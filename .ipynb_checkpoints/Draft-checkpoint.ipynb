# %%
# !python --version
# Out:
# Python 3.5.4 :: Anaconda, Inc.

# %%
import sys
print ("Python {}.{}.{}".format(sys.version_info[0],sys.version_info[1], sys.version_info[2]))
# Out:
# Python 3.5.4

# %% [markdown]
# ## Data Drive Justice
# ---

# %% [markdown]
# ### Guideline
# We are going to collect and analyze data about crimes that would help us to:
# - Reveal patterns relevant to criminal justice, When and where will the next crime take place in a specific region or community
# - Identify interesting uses of these data e.g. identify discriminatory practices or predict future crime events
# - Crime Classification: How does the socio-economic background of a person influence their probability of committing a crime? How does the socio-economic background of the criminal relate to the type of crime committed?
# - Perception of safety among citizens: What factors influence the perception of safety for European citizens?
# - Investigate the relationship between perception of crime and actual crime statistics within communities.
# - Can we explain regional differences, e.g. by looking at the demographics, prevalence of political affiliation or other interesting factors?

# %% [markdown]
# ### Data Science Pipeline
# ---

# %% [markdown]
# Exemplary Procedure Outline:
# Loop 1 (Data Exploration)
# Specify a set of research questions
# Create a data pipeline strategy
# Find and collect datasets
# Have a look at descriptive statistics
# Create new features as needed
# With the data on hand, continue to ask questions:
# Do we still have the same research questions?
# De we still have the same strategy?
# Shall we find other sources?
# ​
# Loop 2 (Data Integration)
# Integrate raw data
# Write scripts for cleaning and aggregation
# Feature selection
# Variable interpretation
# Find correlation between variables
# With the summary on hand, continue to ask question:
# Do we need different variables?
# Do we need to normalize our features?
# Are we still confident we can answer the research question?
# ​
# Loop 3 (Data Analysis)
# Identify the method to respond the target variables
# If is a crime pattern then: Anomaly Detection
# If is a crime circle then: Time Series
# If is a crime category then: Classification
# If is the quantity of crimes then: Regression
# If is a concept and not a target variable then: Density unsupervised
# Etc. (All options enunciative but not limitative)
# Design a concept to visualize the outcome
# Choose and develop the algorithm (e.g. if Classification, SVM or Bayes?)
# Plot the outcomes
# With the summary on hand, ask…
# Does the outcome makes sense?
# What does the important variables mean? (on “human” language)
# How improve the outcome? (add more target variables? Change it? Change the parameters? Change the method?)
# ​
# Loop 4 (Data Communication)
# Document the procedures
# Versioning control of script for replicable science
# Develop a Data Storytelling
# With the Data-story (Notebook, Tableau story, R-Markdown, Slides, etc) on hand, ask… What’s next?
# Improve the model?
# Improve the data?
# Join more researchers to the problem?

# %%
import pandas as pd
import requests
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### European Summary

# %%
data = pd.read_csv('data/crim_hist.tsv', sep='\t', encoding="utf-8")
#data

# %%
data.columns
# Out:
# Index(['unit,geo\time', '2000 ', '1999 ', '1998 ', '1997 ', '1996 ', '1995 ',
#        '1994 ', '1993 ', '1992 ', '1991 ', '1990 ', '1989 ', '1988 ', '1987 ',
#        '1986 ', '1985 ', '1984 ', '1983 ', '1982 ', '1981 ', '1980 ', '1979 ',
#        '1978 ', '1977 ', '1976 ', '1975 ', '1974 ', '1973 ', '1972 ', '1971 ',
#        '1970 ', '1969 ', '1968 ', '1967 ', '1966 ', '1965 ', '1964 ', '1963 ',
#        '1962 ', '1961 ', '1960 ', '1959 ', '1958 ', '1957 ', '1956 ', '1955 ',
#        '1954 ', '1953 ', '1952 ', '1951 ', '1950 '],
#       dtype='object')

# %% [markdown]
# ### Victimhood; offenses and offense groups, 1992-2004
# http://opendata.cbs.nl/ODataApi/OData/37685

# %%
pd.read_csv('data/37685ENG_UntypedDataSet_23112017_155707.csv', sep=';', encoding="utf-8")
# Out:
#     ID   Periods  TotalVictimsOfCrimes_1  SingleVictims_2  MultipleVictims_3  \
# 0    0  1992JJ00                    24.3             18.5                5.9
# 1    1  1993JJ00                    25.0             19.1                6.0
# 2    2  1994JJ00                    26.0             20.8                5.2
# 3    3  1995JJ00                    25.9             20.2                5.7
# 4    4  1996JJ00                    23.1             18.6                4.6
# 5    5  1997JJ00                    25.5             20.4                5.2
# 6    6  1998JJ00                    26.2             20.7                5.4
# 7    7  1999JJ00                    26.2             20.6                5.5
# 8    8  2000JJ00                    25.7             20.7                5.0
# 9    9  2001JJ00                    24.9             19.6                5.4
# 10  10  2002JJ00                    27.2             21.4                5.8
# 11  11  2003JJ00                    25.6             20.5                5.1
# 12  12  2004JJ00                    25.4             20.0                5.3
#
#     TotalViolentCrime_4  SexualCrimes_5  SexualCrimesOnlyWomen_6  Assault_7  \
# 0                   5.4             1.1                      2.1        2.0
# 1                   5.1             1.1                      2.2        1.6
# 2                   5.2             1.3                      2.5        1.3
# 3                   5.4             1.1                      2.2        1.8
# 4                   4.2             0.7                      1.5        1.2
# 5                   5.0             1.2                      2.1        1.4
# 6                   5.6             1.1                      2.0        1.8
# 7                   5.5             1.1                      1.9        1.6
# 8                   5.0             1.0                      1.8        1.3
# 9                   5.8             1.1                      1.8        1.8
# 10                  6.0             1.2                      2.2        1.7
# 11                  5.7             0.9                      1.5        1.9
# 12                  5.2             0.8                      1.5        1.6
#
#     Threats_8       ...        TheftFromCarsIntCarOwnersOnly_17  \
# 0         2.9       ...                                     4.4
# 1         2.8       ...                                     5.0
# 2         3.1       ...                                     3.9
# 3         2.8       ...                                     4.0
# 4         2.5       ...                                     3.6
# 5         2.7       ...                                     3.5
# 6         3.1       ...                                     2.9
# 7         3.3       ...                                     3.3
# 8         3.0       ...                                     3.1
# 9         3.4       ...                                     3.6
# 10        3.7       ...                                     4.3
# 11        3.5       ...                                     4.0
# 12        3.2       ...                                     3.5
#
#     Pickpocketing_18  OtherTheft_19  TotalCasesOfVandalism_20  \
# 0                2.1            4.0                       8.7
# 1                2.2            3.4                      10.3
# 2                2.4            3.3                       9.9
# 3                2.6            3.7                       9.7
# 4                1.8            3.4                       8.8
# 5                2.0            3.3                      10.4
# 6                2.2            3.7                      11.1
# 7                2.0            3.0                      11.6
# 8                2.0            3.1                      11.0
# 9                1.9            2.8                      10.5
# 10               2.0            3.1                      12.1
# 11               1.9            2.7                      11.1
# 12               1.6            3.0                      11.4
#
#     CarVandalismTheftFromCarsExterior_21  CarTheftsExtVandalismCarOwners_22  \
# 0                                    5.4                               12.0
# 1                                    6.4                               14.3
# 2                                    5.9                               13.1
# 3                                    6.0                               12.9
# 4                                    5.8                               12.5
# 5                                    6.2                               11.2
# 6                                    6.6                               12.0
# 7                                    7.1                               12.5
# 8                                    7.0                               12.1
# 9                                    6.6                               11.2
# 10                                   7.8                               13.0
# 11                                   7.6                               12.6
# 12                                   7.5                               12.3
#
#     OtherFormsOfVandalism_23  HitAndRunAccidents_24  HarassmentByPhone_25  \
# 0                        3.5                    1.5                   8.3
# 1                        4.3                    1.2                   7.6
# 2                        4.3                    1.6                   6.6
# 3                        3.9                    1.4                   7.1
# 4                        3.4                    1.3                   6.2
# 5                        4.8                    1.3                   7.2
# 6                        5.1                    1.2                   6.9
# 7                        5.1                    1.5                   6.9
# 8                        4.8                    1.5                   5.7
# 9                        4.4                    1.3                   5.2
# 10                       5.0                    1.5                   4.6
# 11                       4.2                    1.4                   4.8
# 12                       4.7                    1.3                   4.7
#
#     OtherCrimes_26
# 0              0.5
# 1              0.8
# 2              0.6
# 3              0.7
# 4              0.6
# 5              0.5
# 6              0.7
# 7              0.6
# 8              0.6
# 9              0.7
# 10             0.7
# 11             0.8
# 12             0.8
#
# [13 rows x 28 columns]

# %% [markdown]
# ### European Social Survey
# http://www.europeansocialsurvey.org/data/round-index.html

# %%
data = pd.read_stata('data/ESS8e01.stata/ESS8e01.dta', convert_categoricals=False)
#sr = pd.io.stata.StataReader('../Downloads/ESS8e01.stata/ESS8e01.dta')
#vl = sr.value_labels()
#sr.close()

# %%
data.head()
# Out:
#       name  essround edition    proddate  idno cntry  nwspol  netusoft  \
# 0  ESS8e01       8.0     1.0  31.10.2017   1.0    AT   120.0       4.0
# 1  ESS8e01       8.0     1.0  31.10.2017   2.0    AT   120.0       5.0
# 2  ESS8e01       8.0     1.0  31.10.2017   4.0    AT    30.0       2.0
# 3  ESS8e01       8.0     1.0  31.10.2017   6.0    AT    30.0       5.0
# 4  ESS8e01       8.0     1.0  31.10.2017  10.0    AT    30.0       5.0
#
#    netustm  ppltrst    ...     inwshh  inwsmm  inwdde  inwmme  inwyye  inwehh  \
# 0    180.0      8.0    ...        7.0    37.0     5.0    12.0  2016.0     8.0
# 1    120.0      6.0    ...        9.0    39.0    25.0    11.0  2016.0    11.0
# 2   6666.0      5.0    ...       17.0    17.0    22.0    11.0  2016.0    18.0
# 3    120.0      6.0    ...       19.0     9.0    11.0    10.0  2016.0    19.0
# 4    180.0      5.0    ...       10.0    31.0     1.0    12.0  2016.0    11.0
#
#    inwemm  inwtm   dweight   pweight
# 0    33.0   50.0  0.611677  0.370393
# 1    10.0   86.0  1.223354  0.370393
# 2     0.0   38.0  0.389058  0.370393
# 3    59.0   46.0  0.642594  0.370393
# 4    49.0   70.0  3.432402  0.370393
#
# [5 rows x 499 columns]

# %% [markdown]
# ### JSON Editor
# http://jsoneditoronline.org/
#
# ### Data Portal
# https://data.overheid.nl/data/dataset?q=crime&sort=score+desc%2C+modified+desc%2C+metadata_modified+desc

# %% [markdown]
# ### Victims of frequently occurring crime
# https://data.overheid.nl/data/dataset/victims-of-frequently-occurring-crime
# https://opendata.cbs.nl/dataportaal/portal.html?/CBS/nl/dataset/table?graphtype=Table&tableId=37685ENG&_catalog=CBS&_la=nl&_theme=1057

# %%
r = requests.get("http://opendata.cbs.nl/ODataApi/OData/37685ENG")

# %%
service = json.loads(r.text)

# %%
for i in service['value']:
    print (i)
# Out:
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37685ENG/TableInfos', 'name': 'TableInfos'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37685ENG/UntypedDataSet', 'name': 'UntypedDataSet'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37685ENG/TypedDataSet', 'name': 'TypedDataSet'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37685ENG/DataProperties', 'name': 'DataProperties'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37685ENG/CategoryGroups', 'name': 'CategoryGroups'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37685ENG/Periods', 'name': 'Periods'}

# %%
#data = requests.get("http://opendata.cbs.nl/ODataApi/OData/37685ENG/TypedDataSet")

# %%
#json.loads(data.text)

# %%
df_meta = json_normalize(service['value'])
df_meta.index = df_meta['name']
tableinfos = df_meta.loc['TableInfos']['url']
r_tableinfos = requests.get(tableinfos)
json_normalize(json.loads(r_tableinfos.text)['value']).T
# Out:
#                                                                      0
# Catalog                                                            CBS
# DefaultPresentation                                    graphType=table
# DefaultSelection
# Description          \r\n\r\nCONTENTS\r\n\r\n1. General information...
# ExplanatoryText
# Frequency                                                 Discontinued
# GraphTypes                                              Table,Bar,Line
# ID                                                                   0
# Identifier                                                    37685ENG
# Language                                                            en
# MetaDataModified                                   2005-03-07T02:00:00
# Modified                                           2005-03-07T02:00:00
# OutputStatus                                              Discontinued
# Period                                                     1992 - 2004
# ReasonDelivery                                               Undefined
# SearchPriority                                                       1
# ShortDescription     Victims of frequently occurring crime. Violent...
# ShortTitle                                            Victims of crime
# Source                                                            CBS.
# Summary              Victims of frequently occurring crime. Violent...
# Title                            Victims of frequently occurring crime

# %% [markdown]
# ### Crime victims by personal characteristics
# Crime victims by background characteristics: sex, age, highest level of education, number of addresses per km2 of the place of residence 1997 - 2004 Changed on November 07 2005. Frequency: Discontinued.
# https://data.overheid.nl/data/dataset/crime-victims-by-personal-characteristics

# %%
request = requests.get("http://opendata.cbs.nl/ODataApi/OData/37957ENG")
service = json.loads(request.text)
for i in service['value']:
    print (i)
# Out:
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37957ENG/TableInfos', 'name': 'TableInfos'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37957ENG/UntypedDataSet', 'name': 'UntypedDataSet'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37957ENG/TypedDataSet', 'name': 'TypedDataSet'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37957ENG/DataProperties', 'name': 'DataProperties'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37957ENG/CategoryGroups', 'name': 'CategoryGroups'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37957ENG/PersonalCharacteristics', 'name': 'PersonalCharacteristics'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37957ENG/Periods', 'name': 'Periods'}

# %%
def get_datasets(request):
    tuples = []
    for line in json.loads(request.text)['value']:
        url = line['url']
        name = line['name']
        request = requests.get(url)
        table = json_normalize(json.loads(request.text)['value'])
        tuples.append((name,table))
        
    tables = {key: value for (key, value) in tuples}
    print(tables.keys())
    return tables

# %%
#request = requests.get("http://opendata.cbs.nl/ODataApi/OData/37957ENG")
tables = get_datasets(request)

# %%
for key in tables.keys():
    print(key)
# Out:
# DataProperties
# Periods
# TypedDataSet
# TableInfos
# PersonalCharacteristics
# UntypedDataSet
# CategoryGroups

# %% [markdown]
# ---
# We can see the different tables

# %% [markdown]
# - Table infos

# %%
tables['TableInfos'].T
# Out:
#                                                                      0
# Catalog                                                            CBS
# DefaultPresentation                                    graphType=table
# DefaultSelection
# Description          \r\n\r\nCONTENTS\r\n\r\n1. General information...
# ExplanatoryText
# Frequency                                                 Discontinued
# GraphTypes                                              Table,Bar,Line
# ID                                                                   0
# Identifier                                                    37957ENG
# Language                                                            en
# MetaDataModified                                   2005-11-07T02:00:00
# Modified                                           2005-11-07T02:00:00
# OutputStatus                                              Discontinued
# Period                                                     1997 - 2004
# ReasonDelivery                                               Undefined
# SearchPriority                                                       1
# ShortDescription     Crime victims by background characteristics: s...
# ShortTitle                      Crime victims by pers. characteristics
# Source                                                            CBS.
# Summary              Crime victims by background characteristics: s...
# Title                        Crime victims by personal characteristics

# %% [markdown]
# - Periods

# %%
tables['Periods']
# Out:
#   Description       Key      Status Title
# 0        None  1997JJ00  Definitief  1997
# 1        None  1998JJ00  Definitief  1998
# 2        None  1999JJ00  Definitief  1999
# 3        None  2000JJ00  Definitief  2000
# 4        None  2001JJ00  Definitief  2001
# 5        None  2002JJ00  Definitief  2002
# 6        None  2003JJ00  Definitief  2003
# 7        None  2004JJ00  Definitief  2004

# %% [markdown]
# - Data Properties

# %%
tables['DataProperties'].sort_values('Key')
# Out:
#    Datatype  Decimals     Default  \
# 23      NaN       NaN         NaN
# 5       NaN       NaN         NaN
# 11      NaN       NaN         NaN
# 16   Double       1.0  Impossible
# 15   Double       1.0  Impossible
# 14   Double       1.0  Impossible
# 13   Double       1.0  Impossible
# 18   Double       1.0  Impossible
# 17   Double       1.0  Impossible
# 29   Double       1.0  Impossible
# 28   Double       1.0  Impossible
# 30   Double       1.0  Impossible
# 22   Double       1.0  Impossible
# 27   Double       1.0  Impossible
# 1       NaN       NaN         NaN
# 0       NaN       NaN         NaN
# 9    Double       1.0  Impossible
# 21   Double       1.0  Impossible
# 8    Double       1.0  Impossible
# 7    Double       1.0  Impossible
# 20   Double       1.0  Impossible
# 26   Double       1.0  Impossible
# 25   Double       1.0  Impossible
# 19   Double       1.0  Impossible
# 10   Double       1.0  Impossible
# 12   Double       1.0  Impossible
# 24   Double       1.0  Impossible
# 6    Double       1.0  Impossible
# 4    Double       1.0  Impossible
# 3    Double       1.0  Impossible
# 2    Double       1.0  Impossible
#
#                                           Description  ID  \
# 23                                               None  23
# 5                                                None   5
# 11                                               None  11
# 16  Bicycle owners: persons who owned a bicycle at...  16
# 15                                               None  15
# 14                                               None  14
# 13                                               None  13
# 18                                               None  18
# 17                                               None  17
# 29                                               None  29
# 28                                               None  28
# 30                                               None  30
# 22                                               None  22
# 27                                               None  27
# 1                                                None   1
# 0                                                None   0
# 9                                                None   9
# 21                                               None  21
# 8                                                None   8
# 7                                                None   7
# 20                                               None  20
# 26                                               None  26
# 25                                               None  25
# 19                                               None  19
# 10                                               None  10
# 12                                               None  12
# 24                                               None  24
# 6                                                None   6
# 4   Victim of two or more types of offences once o...   4
# 3   Victim of the same type of offence once or mor...   3
# 2   Excluding harassing telephone calls and "other...   2
#
#                                    Key  ParentID  Position ReleasePolicy  \
# 23                                           NaN       NaN           NaN
# 5                                            NaN       NaN           NaN
# 11                                           NaN       NaN           NaN
# 16    BicycleTheftBicycleOwnersOnly_13      11.0      14.0           NaN
# 15                     BicycleTheft_12      11.0      13.0           NaN
# 14           BurglaryOnlyHouseholds_11      11.0      12.0           NaN
# 13                         Burglary_10      11.0      11.0           NaN
# 18             CarTheftCarUsersOnly_15      11.0      16.0           NaN
# 17                         CarTheft_14      11.0      15.0           NaN
# 29                HarassmentByPhone_25       NaN      26.0           NaN
# 28               HitAndRunAccidents_24       NaN      25.0           NaN
# 30                    OtherOffences_26       NaN      27.0           NaN
# 22                      OtherThefts_19      11.0      20.0           NaN
# 27                   OtherVandalism_23      23.0      24.0           NaN
# 1                              Periods       NaN       1.0         False
# 0              PersonalCharacteristics       NaN       0.0           NaN
# 9                      PhysicalAbuse_7       5.0       8.0           NaN
# 21                    Pickpocketing_18      11.0      19.0           NaN
# 8            SexualOffencesOnlyWomen_6       5.0       7.0           NaN
# 7                     SexualOffences_5       5.0       6.0           NaN
# 20        TheftFromCarsCarUsersOnly_17      11.0      18.0           NaN
# 26     TheftFromDamageToCarCarUsers_22      23.0      23.0           NaN
# 25             TheftFromDamageToCar_21      23.0      22.0           NaN
# 19                   TheftsFromCars_16      11.0      17.0           NaN
# 10                            Threat_8       5.0       9.0           NaN
# 12                       TotalThefts_9      11.0      10.0           NaN
# 24                   TotalVandalism_20      23.0      21.0           NaN
# 6                 TotalViolentCrimes_4       5.0       5.0           NaN
# 4   VictimOfMoreThanOneTypeOfOffence_3       NaN       4.0           NaN
# 3        VictimOfTheOneTypeOfOffence_2       NaN       3.0           NaN
# 2                       VictimsTotal_1       NaN       2.0           NaN
#
#                                       Title           Type  \
# 23                          Total vandalism     TopicGroup
# 5                            Violent crimes     TopicGroup
# 11                                   Thefts     TopicGroup
# 16       Bicycle theft; bicycle owners only          Topic
# 15                            Bicycle theft          Topic
# 14                Burglary; only households          Topic
# 13                                 Burglary          Topic
# 18                Car theft; car users only          Topic
# 17                                Car theft          Topic
# 29                      Harassment by phone          Topic
# 28                    Hit-and-run accidents          Topic
# 30                           Other offences          Topic
# 22                             Other thefts          Topic
# 27                          Other vandalism          Topic
# 1                                   Periods  TimeDimension
# 0                  Personal characteristics      Dimension
# 9                            Physical abuse          Topic
# 21                            Pickpocketing          Topic
# 8               Sexual offences; only women          Topic
# 7                           Sexual offences          Topic
# 20          Theft from cars; car users only          Topic
# 26      Theft from/damage to car; car users          Topic
# 25                 Theft from/damage to car          Topic
# 19                         Thefts from cars          Topic
# 10                                   Threat          Topic
# 12                             Total thefts          Topic
# 24                          Total vandalism          Topic
# 6                      Total violent crimes          Topic
# 4   Victim of more than one type of offence          Topic
# 3         Victim of the one type of offence          Topic
# 2                             Victims total          Topic
#
#                                     Unit               odata.type
# 23                                   NaN     Cbs.OData.TopicGroup
# 5                                    NaN     Cbs.OData.TopicGroup
# 11                                   NaN     Cbs.OData.TopicGroup
# 16                 % the group concerned          Cbs.OData.Topic
# 15  % population aged 12 years and older          Cbs.OData.Topic
# 14                 % the group concerned          Cbs.OData.Topic
# 13  % population aged 12 years and older          Cbs.OData.Topic
# 18                 % the group concerned          Cbs.OData.Topic
# 17  % population aged 12 years and older          Cbs.OData.Topic
# 29  % population aged 12 years and older          Cbs.OData.Topic
# 28  % population aged 12 years and older          Cbs.OData.Topic
# 30  % population aged 12 years and older          Cbs.OData.Topic
# 22  % population aged 12 years and older          Cbs.OData.Topic
# 27  % population aged 12 years and older          Cbs.OData.Topic
# 1                                    NaN  Cbs.OData.TimeDimension
# 0                                    NaN      Cbs.OData.Dimension
# 9   % population aged 12 years and older          Cbs.OData.Topic
# 21  % population aged 12 years and older          Cbs.OData.Topic
# 8                  % the group concerned          Cbs.OData.Topic
# 7   % population aged 12 years and older          Cbs.OData.Topic
# 20                 % the group concerned          Cbs.OData.Topic
# 26                 % the group concerned          Cbs.OData.Topic
# 25  % population aged 12 years and older          Cbs.OData.Topic
# 19  % population aged 12 years and older          Cbs.OData.Topic
# 10  % population aged 12 years and older          Cbs.OData.Topic
# 12  % population aged 12 years and older          Cbs.OData.Topic
# 24  % population aged 12 years and older          Cbs.OData.Topic
# 6   % population aged 12 years and older          Cbs.OData.Topic
# 4   % population aged 12 years and older          Cbs.OData.Topic
# 3   % population aged 12 years and older          Cbs.OData.Topic
# 2   % population aged 12 years and older          Cbs.OData.Topic

# %% [markdown]
# - Main Dataset

# %%
tables['TypedDataSet'].describe() #tables['UntypedDataSet'].describe() the untyped df it's plain text
# Out:
#        BicycleTheftBicycleOwnersOnly_13  BicycleTheft_12  \
# count                        785.000000       801.000000
# mean                           5.941274         5.090262
# std                            4.530109         3.898276
# min                            0.200000         0.000000
# 25%                            2.700000         2.200000
# 50%                            4.800000         4.200000
# 75%                            7.900000         6.600000
# max                           21.100000        17.200000
#
#        BurglaryOnlyHouseholds_11  Burglary_10  CarTheftCarUsersOnly_15  \
# count                 120.000000   753.000000               686.000000
# mean                    1.970000     1.719124                 0.342274
# std                     0.921234     0.740134                 0.361291
# min                     0.400000     0.000000                 0.000000
# 25%                     1.400000     1.200000                 0.000000
# 50%                     1.700000     1.700000                 0.300000
# 75%                     2.225000     2.200000                 0.500000
# max                     6.800000     6.500000                 2.400000
#
#        CarTheft_14  HarassmentByPhone_25  HitAndRunAccidents_24          ID  \
# count   729.000000            753.000000             801.000000  824.000000
# mean      0.173251              5.975299               1.509613  411.500000
# std       0.185121              2.534019               0.893893  238.012605
# min       0.000000              1.100000               0.000000    0.000000
# 25%       0.000000              4.200000               1.000000  205.750000
# 50%       0.100000              5.500000               1.400000  411.500000
# 75%       0.300000              7.200000               1.900000  617.250000
# max       1.700000             18.300000               4.900000  823.000000
#
#        OtherOffences_26       ...        TheftFromDamageToCarCarUsers_22  \
# count        753.000000       ...                             686.000000
# mean           0.644887       ...                              11.716618
# std            0.390279       ...                               3.780748
# min            0.000000       ...                               2.600000
# 25%            0.400000       ...                               9.325000
# 50%            0.600000       ...                              11.800000
# 75%            0.900000       ...                              14.175000
# max            3.000000       ...                              22.900000
#
#        TheftFromDamageToCar_21  TheftsFromCars_16    Threat_8  TotalThefts_9  \
# count               729.000000         729.000000  801.000000     801.000000
# mean                  6.163786           1.807545    3.461423      12.749563
# std                   2.761595           1.191435    2.527459       5.698566
# min                   0.000000           0.000000    0.000000       1.000000
# 25%                   4.400000           0.900000    1.700000       8.800000
# 50%                   6.300000           1.800000    3.100000      12.200000
# 75%                   7.900000           2.600000    4.600000      15.900000
# max                  13.700000           5.700000   14.400000      30.300000
#
#        TotalVandalism_20  TotalViolentCrimes_4  \
# count         801.000000            801.000000
# mean           10.273408              5.868914
# std             3.590439              4.226691
# min             0.000000              0.000000
# 25%             8.200000              2.600000
# 50%            10.600000              5.400000
# 75%            12.600000              7.800000
# max            20.100000             20.600000
#
#        VictimOfMoreThanOneTypeOfOffence_3  VictimOfTheOneTypeOfOffence_2  \
# count                          801.000000                     801.000000
# mean                             5.388764                      20.260050
# std                              3.442789                       6.501394
# min                              0.000000                       1.900000
# 25%                              2.800000                      16.400000
# 50%                              5.100000                      21.100000
# 75%                              7.500000                      25.100000
# max                             16.300000                      35.500000
#
#        VictimsTotal_1
# count      801.000000
# mean        25.647566
# std          9.669997
# min          1.900000
# 25%         19.200000
# 50%         26.500000
# 75%         32.700000
# max         50.500000
#
# [8 rows x 27 columns]

# %%
df_victims = tables['TypedDataSet']
df_victims = df_victims.loc[:, df_victims.columns != 'ID']

# %% [markdown]
# Be aware of the data types can be a nightmare

# %%
df_victims['KeyCharacteristics'] = [int(i) for i in df_victims['PersonalCharacteristics']]

# %%
df_victims
# Out:
#           BicycleTheftBicycleOwnersOnly_13  BicycleTheft_12  \
# Periods
# 1997JJ00                               5.7              4.9
# 1998JJ00                               5.8              5.0
# 1999JJ00                               5.3              4.6
# 2000JJ00                               5.7              5.0
# 2001JJ00                               5.3              4.6
# 2002JJ00                               5.2              4.6
# 2003JJ00                               5.2              4.6
# 2004JJ00                               5.4              4.8
# 1997JJ00                               5.9              4.6
# 1998JJ00                               5.8              5.1
# 1999JJ00                               5.9              5.2
# 2000JJ00                               5.9              5.3
# 2001JJ00                               5.3              4.7
# 2002JJ00                               5.6              5.0
# 2003JJ00                               5.7              5.2
# 2004JJ00                               5.5              5.0
# 1997JJ00                               5.5              5.2
# 1998JJ00                               5.8              5.0
# 1999JJ00                               4.7              4.1
# 2000JJ00                               5.5              4.8
# 2001JJ00                               5.3              4.6
# 2002JJ00                               4.8              4.2
# 2003JJ00                               4.8              4.1
# 2004JJ00                               5.3              4.6
# 1997JJ00                               NaN              NaN
# 1998JJ00                               NaN              NaN
# 1999JJ00                               NaN              NaN
# 2000JJ00                               NaN              NaN
# 2001JJ00                               NaN              NaN
# 2002JJ00                               NaN              NaN
# ...                                    ...              ...
# 1999JJ00                               8.0              6.4
# 2000JJ00                               8.6              6.7
# 2001JJ00                               7.1              5.6
# 2002JJ00                               7.7              6.0
# 2003JJ00                               8.2              6.5
# 2004JJ00                               8.2              6.5
# 1997JJ00                               4.3              4.0
# 1998JJ00                               4.4              4.0
# 1999JJ00                               3.9              3.6
# 2000JJ00                               4.1              3.9
# 2001JJ00                               4.1              3.8
# 2002JJ00                               4.3              4.0
# 2003JJ00                               4.1              3.7
# 2004JJ00                               4.3              3.9
# 1997JJ00                               9.1              7.1
# 1998JJ00                               7.6              5.7
# 1999JJ00                               9.7              7.2
# 2000JJ00                              12.1              8.5
# 2001JJ00                               9.1              6.6
# 2002JJ00                               7.7              5.6
# 2003JJ00                               9.2              7.1
# 2004JJ00                               9.9              7.4
# 1997JJ00                               6.1              5.0
# 1998JJ00                               4.4              3.3
# 1999JJ00                              13.5             10.0
# 2000JJ00                              10.0              8.6
# 2001JJ00                              15.6             11.1
# 2002JJ00                              15.9             11.4
# 2003JJ00                              14.9             12.1
# 2004JJ00                               8.6              7.4
#
#           BurglaryOnlyHouseholds_11  Burglary_10  CarTheftCarUsersOnly_15  \
# Periods
# 1997JJ00                        2.6          2.3                      0.4
# 1998JJ00                        1.8          1.6                      0.3
# 1999JJ00                        2.1          1.9                      0.4
# 2000JJ00                        1.8          1.8                      0.4
# 2001JJ00                        1.7          1.6                      0.2
# 2002JJ00                        2.0          1.8                      0.3
# 2003JJ00                        1.3          1.3                      0.2
# 2004JJ00                        1.5          1.5                      0.3
# 1997JJ00                        NaN          2.4                      0.5
# 1998JJ00                        NaN          1.8                      0.3
# 1999JJ00                        NaN          1.8                      0.4
# 2000JJ00                        NaN          1.9                      0.5
# 2001JJ00                        NaN          1.6                      0.2
# 2002JJ00                        NaN          1.9                      0.4
# 2003JJ00                        NaN          1.5                      0.2
# 2004JJ00                        NaN          1.5                      0.2
# 1997JJ00                        NaN          2.3                      0.2
# 1998JJ00                        NaN          1.5                      0.4
# 1999JJ00                        NaN          1.9                      0.4
# 2000JJ00                        NaN          1.6                      0.4
# 2001JJ00                        NaN          1.7                      0.3
# 2002JJ00                        NaN          1.8                      0.3
# 2003JJ00                        NaN          1.1                      0.3
# 2004JJ00                        NaN          1.4                      0.5
# 1997JJ00                        NaN          NaN                      NaN
# 1998JJ00                        NaN          NaN                      NaN
# 1999JJ00                        NaN          NaN                      NaN
# 2000JJ00                        NaN          NaN                      NaN
# 2001JJ00                        NaN          NaN                      NaN
# 2002JJ00                        NaN          NaN                      NaN
# ...                             ...          ...                      ...
# 1999JJ00                        2.4          2.2                      0.7
# 2000JJ00                        2.1          2.2                      0.8
# 2001JJ00                        1.7          1.7                      0.4
# 2002JJ00                        2.0          1.9                      0.7
# 2003JJ00                        1.5          1.5                      0.2
# 2004JJ00                        1.7          1.5                      0.4
# 1997JJ00                        2.3          1.9                      0.6
# 1998JJ00                        1.3          1.3                      0.4
# 1999JJ00                        1.7          1.6                      0.3
# 2000JJ00                        1.5          1.6                      0.3
# 2001JJ00                        1.6          1.5                      0.2
# 2002JJ00                        1.7          1.6                      0.2
# 2003JJ00                        1.1          1.1                      0.2
# 2004JJ00                        1.4          1.3                      0.3
# 1997JJ00                        2.2          2.5                      1.1
# 1998JJ00                        2.6          2.5                      1.2
# 1999JJ00                        2.5          2.4                      0.8
# 2000JJ00                        2.1          2.2                      1.2
# 2001JJ00                        1.5          1.7                      0.2
# 2002JJ00                        2.2          2.3                      0.8
# 2003JJ00                        1.4          1.8                      0.5
# 2004JJ00                        1.6          1.6                      0.4
# 1997JJ00                        2.7          2.4                      0.0
# 1998JJ00                        2.2          2.4                      0.0
# 1999JJ00                        4.3          3.3                      0.5
# 2000JJ00                        3.4          3.1                      1.2
# 2001JJ00                        4.5          4.0                      2.3
# 2002JJ00                        5.2          4.8                      0.7
# 2003JJ00                        4.0          3.8                      0.0
# 2004JJ00                        3.3          3.3                      0.7
#
#           CarTheft_14  HarassmentByPhone_25  HitAndRunAccidents_24  \
# Periods
# 1997JJ00          0.2                   7.2                    1.4
# 1998JJ00          0.2                   6.9                    1.3
# 1999JJ00          0.2                   6.9                    1.5
# 2000JJ00          0.3                   5.7                    1.5
# 2001JJ00          0.1                   5.2                    1.4
# 2002JJ00          0.2                   4.6                    1.6
# 2003JJ00          0.1                   4.8                    1.5
# 2004JJ00          0.2                   4.7                    1.4
# 1997JJ00          0.3                   5.1                    1.9
# 1998JJ00          0.2                   5.1                    1.4
# 1999JJ00          0.3                   5.4                    1.8
# 2000JJ00          0.3                   4.1                    1.9
# 2001JJ00          0.2                   4.6                    1.6
# 2002JJ00          0.3                   3.6                    2.0
# 2003JJ00          0.1                   3.9                    1.6
# 2004JJ00          0.1                   3.6                    1.5
# 1997JJ00          0.1                   9.3                    1.0
# 1998JJ00          0.2                   8.7                    1.2
# 1999JJ00          0.2                   8.3                    1.2
# 2000JJ00          0.2                   7.3                    1.2
# 2001JJ00          0.1                   5.9                    1.2
# 2002JJ00          0.1                   5.6                    1.2
# 2003JJ00          0.1                   5.8                    1.3
# 2004JJ00          0.2                   5.9                    1.3
# 1997JJ00          NaN                   NaN                    NaN
# 1998JJ00          NaN                   NaN                    NaN
# 1999JJ00          NaN                   NaN                    NaN
# 2000JJ00          NaN                   NaN                    NaN
# 2001JJ00          NaN                   NaN                    NaN
# 2002JJ00          NaN                   NaN                    NaN
# ...               ...                   ...                    ...
# 1999JJ00          0.4                   8.9                    1.7
# 2000JJ00          0.4                   6.9                    1.4
# 2001JJ00          0.2                   6.4                    1.2
# 2002JJ00          0.3                   5.9                    1.7
# 2003JJ00          0.1                   5.9                    1.4
# 2004JJ00          0.2                   5.7                    1.4
# 1997JJ00          0.3                   6.2                    1.8
# 1998JJ00          0.2                   6.6                    1.4
# 1999JJ00          0.2                   6.6                    1.4
# 2000JJ00          0.2                   5.5                    1.5
# 2001JJ00          0.1                   5.1                    1.3
# 2002JJ00          0.1                   4.3                    1.5
# 2003JJ00          0.1                   4.6                    1.5
# 2004JJ00          0.2                   4.5                    1.5
# 1997JJ00          0.5                  10.2                    0.8
# 1998JJ00          0.5                  11.0                    2.1
# 1999JJ00          0.4                   7.8                    2.0
# 2000JJ00          0.5                   6.6                    1.7
# 2001JJ00          0.1                   5.4                    1.5
# 2002JJ00          0.4                   5.8                    1.6
# 2003JJ00          0.3                   5.2                    1.3
# 2004JJ00          0.2                   5.6                    1.0
# 1997JJ00          0.0                   8.0                    1.5
# 1998JJ00          0.0                   6.0                    1.0
# 1999JJ00          0.2                   6.6                    1.6
# 2000JJ00          0.6                   6.3                    0.5
# 2001JJ00          1.0                   6.7                    1.3
# 2002JJ00          0.3                   4.9                    2.9
# 2003JJ00          0.0                   7.9                    2.5
# 2004JJ00          0.3                   4.5                    0.9
#
#           OtherOffences_26  OtherThefts_19         ...          \
# Periods                                            ...
# 1997JJ00               0.5             3.4         ...
# 1998JJ00               0.7             3.9         ...
# 1999JJ00               0.6             3.1         ...
# 2000JJ00               0.6             3.1         ...
# 2001JJ00               0.7             3.0         ...
# 2002JJ00               0.7             3.1         ...
# 2003JJ00               0.8             2.8         ...
# 2004JJ00               0.8             3.1         ...
# 1997JJ00               0.6             3.9         ...
# 1998JJ00               0.6             3.6         ...
# 1999JJ00               0.6             3.1         ...
# 2000JJ00               0.5             3.1         ...
# 2001JJ00               0.7             3.2         ...
# 2002JJ00               0.6             3.0         ...
# 2003JJ00               0.9             2.7         ...
# 2004JJ00               0.8             3.0         ...
# 1997JJ00               0.5             3.0         ...
# 1998JJ00               0.7             4.1         ...
# 1999JJ00               0.6             3.2         ...
# 2000JJ00               0.7             3.1         ...
# 2001JJ00               0.6             2.8         ...
# 2002JJ00               0.8             3.3         ...
# 2003JJ00               0.7             2.8         ...
# 2004JJ00               0.7             3.2         ...
# 1997JJ00               NaN             NaN         ...
# 1998JJ00               NaN             NaN         ...
# 1999JJ00               NaN             NaN         ...
# 2000JJ00               NaN             NaN         ...
# 2001JJ00               NaN             NaN         ...
# 2002JJ00               NaN             NaN         ...
# ...                    ...             ...         ...
# 1999JJ00               0.5             3.0         ...
# 2000JJ00               0.9             3.0         ...
# 2001JJ00               0.7             2.6         ...
# 2002JJ00               0.7             2.7         ...
# 2003JJ00               0.8             3.0         ...
# 2004JJ00               0.9             2.8         ...
# 1997JJ00               0.7             3.1         ...
# 1998JJ00               0.9             3.2         ...
# 1999JJ00               0.5             3.3         ...
# 2000JJ00               0.5             3.1         ...
# 2001JJ00               0.6             2.9         ...
# 2002JJ00               0.7             3.4         ...
# 2003JJ00               0.7             2.6         ...
# 2004JJ00               0.7             3.4         ...
# 1997JJ00               0.3             4.6         ...
# 1998JJ00               0.8             5.1         ...
# 1999JJ00               0.9             2.5         ...
# 2000JJ00               0.7             3.0         ...
# 2001JJ00               0.7             2.9         ...
# 2002JJ00               0.7             2.3         ...
# 2003JJ00               1.0             2.9         ...
# 2004JJ00               0.9             2.2         ...
# 1997JJ00               0.7             5.3         ...
# 1998JJ00               0.6             5.0         ...
# 1999JJ00               0.4             3.7         ...
# 2000JJ00               1.0             3.9         ...
# 2001JJ00               0.8             5.0         ...
# 2002JJ00               0.3             2.7         ...
# 2003JJ00               1.7             5.9         ...
# 2004JJ00               0.7             2.9         ...
#
#           TheftFromDamageToCar_21 TheftsFromCars_16 Threat_8  TotalThefts_9  \
# Periods
# 1997JJ00                      6.2               1.9      2.9           13.3
# 1998JJ00                      6.6               1.6      3.2           13.0
# 1999JJ00                      7.1               1.9      3.4           12.6
# 2000JJ00                      7.0               1.8      3.1           12.4
# 2001JJ00                      6.6               2.1      3.5           12.1
# 2002JJ00                      7.8               2.6      3.7           12.9
# 2003JJ00                      7.6               2.4      3.6           11.9
# 2004JJ00                      7.5               2.1      3.3           12.1
# 1997JJ00                      7.9               2.6      3.9           13.4
# 1998JJ00                      8.4               2.4      4.8           13.1
# 1999JJ00                      8.7               2.4      4.9           12.9
# 2000JJ00                      8.4               2.7      4.0           13.0
# 2001JJ00                      7.7               2.8      4.5           12.8
# 2002JJ00                      8.9               3.3      5.1           13.5
# 2003JJ00                      8.9               2.8      5.0           12.5
# 2004JJ00                      8.3               2.6      4.5           12.3
# 1997JJ00                      4.5               1.3      2.0           13.3
# 1998JJ00                      5.0               0.9      1.7           13.0
# 1999JJ00                      5.6               1.4      1.9           12.4
# 2000JJ00                      5.6               0.9      2.2           11.9
# 2001JJ00                      5.5               1.4      2.4           11.5
# 2002JJ00                      6.6               1.8      2.3           12.3
# 2003JJ00                      6.2               2.0      2.2           11.4
# 2004JJ00                      6.7               1.7      2.1           11.9
# 1997JJ00                      NaN               NaN      NaN            NaN
# 1998JJ00                      NaN               NaN      NaN            NaN
# 1999JJ00                      NaN               NaN      NaN            NaN
# 2000JJ00                      NaN               NaN      NaN            NaN
# 2001JJ00                      NaN               NaN      NaN            NaN
# 2002JJ00                      NaN               NaN      NaN            NaN
# ...                           ...               ...      ...            ...
# 1999JJ00                      7.0               1.7      3.6           14.4
# 2000JJ00                      6.4               1.6      3.0           14.8
# 2001JJ00                      5.8               1.9      3.8           13.1
# 2002JJ00                      6.6               2.0      3.2           14.2
# 2003JJ00                      6.9               2.0      3.8           14.1
# 2004JJ00                      6.2               2.2      4.0           13.4
# 1997JJ00                      5.5               1.6      3.1           11.7
# 1998JJ00                      6.4               1.7      2.9           11.2
# 1999JJ00                      7.1               1.7      3.1           11.1
# 2000JJ00                      6.7               1.5      3.1           10.8
# 2001JJ00                      6.6               2.1      3.1           10.9
# 2002JJ00                      7.8               2.4      3.6           11.9
# 2003JJ00                      7.4               2.1      3.5           10.4
# 2004JJ00                      7.7               2.0      3.0           11.3
# 1997JJ00                      6.6               2.7      2.8           18.4
# 1998JJ00                      5.5               2.6      3.9           18.9
# 1999JJ00                      7.3               2.2      4.0           16.2
# 2000JJ00                      8.0               3.0      3.0           17.7
# 2001JJ00                      7.0               2.4      4.5           15.0
# 2002JJ00                      8.0               3.1      3.9           14.9
# 2003JJ00                      8.4               3.7      3.7           16.7
# 2004JJ00                      7.3               2.6      3.8           14.3
# 1997JJ00                      3.3               2.3      2.5           13.7
# 1998JJ00                      5.8               0.1      3.1           12.2
# 1999JJ00                      6.7               2.5      5.0           19.9
# 2000JJ00                      5.7               1.2      2.9           16.9
# 2001JJ00                      5.4               1.3      5.7           22.2
# 2002JJ00                      6.0               2.2      2.5           24.0
# 2003JJ00                      5.8               2.5      5.0           21.3
# 2004JJ00                      5.1               2.0      5.5           15.7
#
#           TotalVandalism_20  TotalViolentCrimes_4  \
# Periods
# 1997JJ00               10.4                   5.2
# 1998JJ00               11.1                   5.7
# 1999JJ00               11.6                   5.6
# 2000JJ00               11.1                   5.1
# 2001JJ00               10.6                   5.9
# 2002JJ00               12.0                   6.0
# 2003JJ00               11.0                   5.8
# 2004JJ00               11.4                   5.3
# 1997JJ00               12.3                   6.0
# 1998JJ00               12.5                   7.3
# 1999JJ00               12.6                   7.1
# 2000JJ00               12.4                   5.8
# 2001JJ00               11.6                   7.0
# 2002JJ00               13.3                   7.2
# 2003JJ00               12.4                   7.5
# 2004JJ00               12.4                   6.5
# 1997JJ00                8.4                   4.5
# 1998JJ00                9.7                   4.1
# 1999JJ00               10.7                   4.2
# 2000JJ00                9.8                   4.4
# 2001JJ00                9.5                   4.8
# 2002JJ00               10.8                   4.9
# 2003JJ00                9.5                   4.2
# 2004JJ00               10.4                   4.1
# 1997JJ00                NaN                   NaN
# 1998JJ00                NaN                   NaN
# 1999JJ00                NaN                   NaN
# 2000JJ00                NaN                   NaN
# 2001JJ00                NaN                   NaN
# 2002JJ00                NaN                   NaN
# ...                     ...                   ...
# 1999JJ00               11.4                   6.9
# 2000JJ00               10.8                   5.4
# 2001JJ00                9.4                   6.6
# 2002JJ00               10.8                   5.9
# 2003JJ00               10.2                   7.0
# 2004JJ00               10.3                   6.6
# 1997JJ00                9.9                   4.9
# 1998JJ00               10.9                   5.1
# 1999JJ00               11.4                   5.1
# 2000JJ00               10.6                   4.8
# 2001JJ00               10.6                   5.3
# 2002JJ00               12.0                   5.8
# 2003JJ00               10.6                   5.4
# 2004JJ00               11.6                   4.8
# 1997JJ00               11.2                   5.2
# 1998JJ00               10.4                   7.9
# 1999JJ00               11.7                   7.3
# 2000JJ00               12.8                   6.0
# 2001JJ00               10.2                   7.5
# 2002JJ00               12.3                   6.7
# 2003JJ00               12.5                   7.3
# 2004JJ00               10.9                   6.5
# 1997JJ00                7.2                   5.7
# 1998JJ00                9.8                   5.6
# 1999JJ00               15.6                   7.0
# 2000JJ00               11.0                   5.8
# 2001JJ00               12.0                  10.9
# 2002JJ00               10.7                   7.5
# 2003JJ00               10.5                   8.7
# 2004JJ00               11.0                   9.6
#
#           VictimOfMoreThanOneTypeOfOffence_3  VictimOfTheOneTypeOfOffence_2  \
# Periods
# 1997JJ00                                 5.3                           20.6
# 1998JJ00                                 5.5                           20.9
# 1999JJ00                                 5.5                           21.0
# 2000JJ00                                 5.1                           21.0
# 2001JJ00                                 5.4                           19.8
# 2002JJ00                                 5.8                           21.5
# 2003JJ00                                 5.0                           20.7
# 2004JJ00                                 5.4                           20.2
# 1997JJ00                                 6.2                           21.7
# 1998JJ00                                 6.4                           22.4
# 1999JJ00                                 6.3                           22.3
# 2000JJ00                                 5.9                           22.3
# 2001JJ00                                 5.9                           21.7
# 2002JJ00                                 6.7                           23.1
# 2003JJ00                                 6.0                           22.4
# 2004JJ00                                 6.0                           21.6
# 1997JJ00                                 4.3                           19.5
# 1998JJ00                                 4.6                           19.3
# 1999JJ00                                 4.8                           19.7
# 2000JJ00                                 4.3                           19.7
# 2001JJ00                                 5.0                           17.9
# 2002JJ00                                 5.0                           19.8
# 2003JJ00                                 4.0                           19.1
# 2004JJ00                                 4.9                           18.9
# 1997JJ00                                 NaN                            NaN
# 1998JJ00                                 NaN                            NaN
# 1999JJ00                                 NaN                            NaN
# 2000JJ00                                 NaN                            NaN
# 2001JJ00                                 NaN                            NaN
# 2002JJ00                                 NaN                            NaN
# ...                                      ...                            ...
# 1999JJ00                                 6.9                           21.2
# 2000JJ00                                 5.9                           21.3
# 2001JJ00                                 6.0                           18.8
# 2002JJ00                                 5.9                           21.2
# 2003JJ00                                 6.3                           20.7
# 2004JJ00                                 6.0                           20.4
# 1997JJ00                                 4.3                           19.8
# 1998JJ00                                 4.4                           20.2
# 1999JJ00                                 4.6                           20.4
# 2000JJ00                                 4.3                           20.0
# 2001JJ00                                 4.7                           19.3
# 2002JJ00                                 5.4                           21.0
# 2003JJ00                                 4.3                           19.7
# 2004JJ00                                 5.1                           19.6
# 1997JJ00                                 6.2                           23.7
# 1998JJ00                                 7.8                           23.8
# 1999JJ00                                 7.5                           22.8
# 2000JJ00                                 7.2                           25.1
# 2001JJ00                                 7.1                           20.5
# 2002JJ00                                 7.0                           21.7
# 2003JJ00                                 7.1                           24.8
# 2004JJ00                                 6.3                           21.6
# 1997JJ00                                 5.8                           17.0
# 1998JJ00                                 4.9                           19.5
# 1999JJ00                                11.2                           21.7
# 2000JJ00                                 8.2                           18.6
# 2001JJ00                                11.0                           25.5
# 2002JJ00                                 7.1                           31.2
# 2003JJ00                                11.0                           21.8
# 2004JJ00                                 6.2                           25.5
#
#           VictimsTotal_1  KeyCharacteristics
# Periods
# 1997JJ00            25.8                  10
# 1998JJ00            26.4                  10
# 1999JJ00            26.5                  10
# 2000JJ00            26.0                  10
# 2001JJ00            25.2                  10
# 2002JJ00            27.3                  10
# 2003JJ00            25.7                  10
# 2004JJ00            25.6                  10
# 1997JJ00            27.9                  11
# 1998JJ00            28.8                  11
# 1999JJ00            28.6                  11
# 2000JJ00            28.1                  11
# 2001JJ00            27.5                  11
# 2002JJ00            29.8                  11
# 2003JJ00            28.4                  11
# 2004JJ00            27.5                  11
# 1997JJ00            23.9                  12
# 1998JJ00            24.0                  12
# 1999JJ00            24.5                  12
# 2000JJ00            23.9                  12
# 2001JJ00            22.9                  12
# 2002JJ00            24.8                  12
# 2003JJ00            23.1                  12
# 2004JJ00            23.8                  12
# 1997JJ00             NaN                  13
# 1998JJ00             NaN                  13
# 1999JJ00             NaN                  13
# 2000JJ00             NaN                  13
# 2001JJ00             NaN                  13
# 2002JJ00             NaN                  13
# ...                  ...                 ...
# 1999JJ00            28.1                  73
# 2000JJ00            27.3                  73
# 2001JJ00            24.8                  73
# 2002JJ00            27.1                  73
# 2003JJ00            27.0                  73
# 2004JJ00            26.4                  73
# 1997JJ00            24.1                  74
# 1998JJ00            24.6                  74
# 1999JJ00            25.0                  74
# 2000JJ00            24.3                  74
# 2001JJ00            24.0                  74
# 2002JJ00            26.4                  74
# 2003JJ00            23.9                  74
# 2004JJ00            24.7                  74
# 1997JJ00            29.9                  75
# 1998JJ00            31.6                  75
# 1999JJ00            30.3                  75
# 2000JJ00            32.2                  75
# 2001JJ00            27.7                  75
# 2002JJ00            28.7                  75
# 2003JJ00            31.8                  75
# 2004JJ00            27.8                  75
# 1997JJ00            22.8                  76
# 1998JJ00            24.5                  76
# 1999JJ00            32.9                  76
# 2000JJ00            26.8                  76
# 2001JJ00            36.4                  76
# 2002JJ00            38.3                  76
# 2003JJ00            32.9                  76
# 2004JJ00            31.6                  76
#
# [824 rows x 29 columns]

# %% [markdown]
# - Personal Characteristics

# %%
tables['PersonalCharacteristics']
#Show all categories
#for i in df_characteristics['Title']:
#    print(i)
# Out:
#      CategoryGroupID                                        Description  Key  \
# 0                  1                                               None  10
# 1                  2                                               None  11
# 2                  2                                               None  12
# 3                  3                                    Age category 1.  13
# 4                  3                                    Age category 1.  14
# 5                  3                                    Age category 1.  15
# 6                  3                                    Age category 1.  16
# 7                  3                                    Age category 1.  17
# 8                  3                                    Age category 1.  18
# 9                  3                                    Age category 1.  19
# 10                 3                                    Age category 1.  20
# 11                 3                                    Age category 1.  21
# 12                 4  Age category 2.\r\nStandard age category: vers...  111
# 13                 4  Age category 2.\r\nStandard age category: vers...  112
# 14                 4  Age category 2.\r\nStandard age category: vers...  113
# 15                 4  Age category 2.\r\nStandard age category: vers...  114
# 16                 4  Age category 2.\r\nStandard age category: vers...  115
# 17                 5  Age category 3.\r\nStandard age category: vers...  121
# 18                 5  Age category 3.\r\nStandard age category: vers...  122
# 19                 5  Age category 3.\r\nStandard age category: vers...  123
# 20                 5  Age category 3.\r\nStandard age category: vers...  124
# 21                 5  Age category 3.\r\nStandard age category: vers...  125
# 22                 5  Age category 3.\r\nStandard age category: vers...  126
# 23                 5  Age category 3.\r\nStandard age category: vers...  127
# 24                 5  Age category 3.\r\nStandard age category: vers...  128
# 25                 5  Age category 3.\r\nStandard age category: vers...  129
# 26                 5  Age category 3.\r\nStandard age category: vers...  130
# 27                 6                  Age category 4.\r\nAge by gender.  90
# 28                 6                  Age category 4.\r\nAge by gender.  92
# 29                 6                  Age category 4.\r\nAge by gender.  94
# ..               ...                                                ...  ...
# 73                 9  Highest level of education: primary education....  22
# 74                 9  Highest level of education: pre-vocational edu...  23
# 75                 9  Highest level of education: junior general sec...  24
# 76                 9  Highest level of education: senior general sec...  25
# 77                 9  Highest level of education: vocational college...  26
# 78                10                                               None  27
# 79                10                                               None  28
# 80                10                                               None  29
# 81                10                                               None  30
# 82                10                                               None  31
# 83                10                                               None  32
# 84                10                                               None  33
# 85                10                                               None  34
# 86                10                                               None  35
# 87                10                                               None  36
# 88                10                                               None  37
# 89                11                                               None  38
# 90                11                                   Parent or child.  39
# 91                11                                               None  40
# 92                11                                   Parent or child.  41
# 93                12                   2,500 or more addresses per km2.  46
# 94                12                   1,500 - 2,500 addresses per km2.  45
# 95                12                   1,000 - 1,500 addresses per km2.  44
# 96                12                     500 - 1,000 addresses per km2.  43
# 97                12                  Fewer than 500 addresses per km2.  42
# 98                13                                               None  72
# 99                13                                               None  73
# 100               14                                               None  74
# 101               14                                               None  75
# 102               14                                               None  76
#
#                                         Title  KeyCharacteristics
# 0              Total personal characteristics                  10
# 1                                         Men                  11
# 2                                       Women                  12
# 3                        Age cat. 1: 0-11 yrs                  13
# 4                       Age cat. 1: 12-17 yrs                  14
# 5                       Age cat. 1: 18-24 yrs                  15
# 6                      Age cat. 1:  25-34 yrs                  16
# 7                       Age cat. 1: 35-44 yrs                  17
# 8                       Age cat. 1: 45-54 yrs                  18
# 9                       Age cat. 1: 55-64 yrs                  19
# 10                      age cat. 1: 65-74 yrs                  20
# 11               Age cat. 1: 75 yrs and older                  21
# 12                       Age cat. 2: 0-14 yrs                 111
# 13                      Age cat. 2: 15-24 yrs                 112
# 14                      Age cat. 2: 25-44 yrs                 113
# 15                      Age cat. 2: 45-64 yrs                 114
# 16               Age cat. 2: 65 yrs and older                 115
# 17                       Age cat. 3: 0-14 yrs                 121
# 18                      Age cat. 3: 15-19 yrs                 122
# 19                      Age cat. 3: 20-24 yrs                 123
# 20                      Age cat. 3: 25-34 yrs                 124
# 21                      Age cat. 3: 35-44 yrs                 125
# 22                      Age cat. 3: 45-54 yrs                 126
# 23                      Age cat. 3: 55-64 yrs                 127
# 24                      Age cat. 3: 65-74 yrs                 128
# 25                      Age cat. 3: 75-84 yrs                 129
# 26               Age cat. 3: 85 yrs and older                 130
# 27        Age cat. 4 x gender: men, 12-17 yrs                  90
# 28        Age cat. 4 x gender: men, 18-24 yrs                  92
# 29        Age cat. 4 x gender: men, 25-34 yrs                  94
# ..                                        ...                 ...
# 73      Level of education: primary education                  22
# 74     Level of education: pre-vocational ed.                  23
# 75     Level of education: jun. gen. sec. ed.                  24
# 76   Level of ed.:sen.gen.sec.ed.,sen.voc.ed.                  25
# 77      Level of ed.: voc.college, university                  26
# 78                 Higher executive positions                  27
# 79             Other non-physical occupations                  28
# 80                      Self-employed persons                  29
# 81                             Skilled labour                  30
# 82           Semiskilled and unskilled labour                  31
# 83                    Unemployed labour force                  32
# 84     Still attending some form of education                  33
# 85                             Unable to work                  34
# 86              Early retirement (58-64 year)                  35
# 87      Housekeeping with child(ren) under 18                  36
# 88              Other socio-economic brackets                  37
# 89                      One-person households                  38
# 90                     Single parent families                  39
# 91                    Couple without children                  40
# 92                       Couple with children                  41
# 93            2,500 or more addresses per km2                  46
# 94            1,500 - 2,500 addresses per km2                  45
# 95            1,000 - 1,500 addresses per km2                  44
# 96              500 - 1,000 addresses per km2                  43
# 97                    < 500 addresses per km2                  42
# 98                                House-owner                  72
# 99                             No house-owner                  73
# 100             Single-family/detached houses                  74
# 101                               Flats, etc.                  75
# 102                  Other types of dwellings                  76
#
# [103 rows x 5 columns]

# %%
df_characteristics = tables['PersonalCharacteristics']
df_characteristics['KeyCharacteristics'] = [int(i) for i in df_characteristics['Key']]
df_characteristics = df_characteristics[['Title','CategoryGroupID','KeyCharacteristics']]

# %%
df_characteristics.head()
# Out:
#                             Title  CategoryGroupID  KeyCharacteristics
# 0  Total personal characteristics                1                  10
# 1                             Men                2                  11
# 2                           Women                2                  12
# 3            Age cat. 1: 0-11 yrs                3                  13
# 4           Age cat. 1: 12-17 yrs                3                  14

# %% [markdown]
# ### Tables integration

# %%
df_victims_cha = pd.merge(df_victims, df_characteristics, on='KeyCharacteristics', how='left')

# %%
df_victims_cha.index = df_victims_cha['Periods']

# %%
df_victims_cha.head()
# Out:
#           BicycleTheftBicycleOwnersOnly_13  BicycleTheft_12  \
# Periods
# 1997JJ00                               5.7              4.9
# 1998JJ00                               5.8              5.0
# 1999JJ00                               5.3              4.6
# 2000JJ00                               5.7              5.0
# 2001JJ00                               5.3              4.6
#
#           BurglaryOnlyHouseholds_11  Burglary_10  CarTheftCarUsersOnly_15  \
# Periods
# 1997JJ00                        2.6          2.3                      0.4
# 1998JJ00                        1.8          1.6                      0.3
# 1999JJ00                        2.1          1.9                      0.4
# 2000JJ00                        1.8          1.8                      0.4
# 2001JJ00                        1.7          1.6                      0.2
#
#           CarTheft_14  HarassmentByPhone_25  HitAndRunAccidents_24  \
# Periods
# 1997JJ00          0.2                   7.2                    1.4
# 1998JJ00          0.2                   6.9                    1.3
# 1999JJ00          0.2                   6.9                    1.5
# 2000JJ00          0.3                   5.7                    1.5
# 2001JJ00          0.1                   5.2                    1.4
#
#           OtherOffences_26  OtherThefts_19       ...         Threat_8  \
# Periods                                          ...
# 1997JJ00               0.5             3.4       ...              2.9
# 1998JJ00               0.7             3.9       ...              3.2
# 1999JJ00               0.6             3.1       ...              3.4
# 2000JJ00               0.6             3.1       ...              3.1
# 2001JJ00               0.7             3.0       ...              3.5
#
#          TotalThefts_9 TotalVandalism_20  TotalViolentCrimes_4  \
# Periods
# 1997JJ00          13.3              10.4                   5.2
# 1998JJ00          13.0              11.1                   5.7
# 1999JJ00          12.6              11.6                   5.6
# 2000JJ00          12.4              11.1                   5.1
# 2001JJ00          12.1              10.6                   5.9
#
#           VictimOfMoreThanOneTypeOfOffence_3  VictimOfTheOneTypeOfOffence_2  \
# Periods
# 1997JJ00                                 5.3                           20.6
# 1998JJ00                                 5.5                           20.9
# 1999JJ00                                 5.5                           21.0
# 2000JJ00                                 5.1                           21.0
# 2001JJ00                                 5.4                           19.8
#
#           VictimsTotal_1  KeyCharacteristics                           Title  \
# Periods
# 1997JJ00            25.8                  10  Total personal characteristics
# 1998JJ00            26.4                  10  Total personal characteristics
# 1999JJ00            26.5                  10  Total personal characteristics
# 2000JJ00            26.0                  10  Total personal characteristics
# 2001JJ00            25.2                  10  Total personal characteristics
#
#           CategoryGroupID
# Periods
# 1997JJ00                1
# 1998JJ00                1
# 1999JJ00                1
# 2000JJ00                1
# 2001JJ00                1
#
# [5 rows x 31 columns]

# %% [markdown]
# #### What to do?
# - Group the characteristics and see the time series per crime
# - Pick one year and see the characteristics
# - Group the year and see the characteristics
# - Group by crime type, group by general characteristics, choose last year

# %%
#Choose last period, and the total crimes 
df_victims_2004 = df_victims_cha.loc['2004JJ00'][['Title','CategoryGroupID',  'TotalThefts_9','TotalVandalism_20','TotalViolentCrimes_4']]

# %%
df_victims_2004.head()
# Out:
#                                    Title  CategoryGroupID  TotalThefts_9  \
# Periods
# 2004JJ00  Total personal characteristics                1           12.1
# 2004JJ00                             Men                2           12.3
# 2004JJ00                           Women                2           11.9
# 2004JJ00            Age cat. 1: 0-11 yrs                3            NaN
# 2004JJ00           Age cat. 1: 12-17 yrs                3           18.2
#
#           TotalVandalism_20  TotalViolentCrimes_4
# Periods
# 2004JJ00               11.4                   5.3
# 2004JJ00               12.4                   6.5
# 2004JJ00               10.4                   4.1
# 2004JJ00                NaN                   NaN
# 2004JJ00               11.5                  10.7

# %%
plt.figure(figsize=(25, 10))
plt.bar(df_victims_2004['Title'], df_victims_2004['TotalThefts_9'])
# Out:
# <Container object of 103 artists>

# %%
#plt.figure(figsize=(20, 10))
#for serie in tablita:
#    plt.plot(tablita['PersonalCharacteristics'], tablita[str(serie)])

# %%
df_characteristics[df_characteristics['CategoryGroupID'] == 9]
# Out:
#     CategoryGroupID                                        Description  Key  \
# 73                9  Highest level of education: primary education....  22
# 74                9  Highest level of education: pre-vocational edu...  23
# 75                9  Highest level of education: junior general sec...  24
# 76                9  Highest level of education: senior general sec...  25
# 77                9  Highest level of education: vocational college...  26
#
#                                        Title
# 73     Level of education: primary education
# 74    Level of education: pre-vocational ed.
# 75    Level of education: jun. gen. sec. ed.
# 76  Level of ed.:sen.gen.sec.ed.,sen.voc.ed.
# 77     Level of ed.: voc.college, university

# %%
temp_table = df_victims_2004[df_victims_2004['CategoryGroupID'] == 9]
temp_table
# Out:
#                                              Title  CategoryGroupID  \
# Periods
# 2004JJ00     Level of education: primary education                9
# 2004JJ00    Level of education: pre-vocational ed.                9
# 2004JJ00    Level of education: jun. gen. sec. ed.                9
# 2004JJ00  Level of ed.:sen.gen.sec.ed.,sen.voc.ed.                9
# 2004JJ00     Level of ed.: voc.college, university                9
#
#           TotalThefts_9  TotalVandalism_20  TotalViolentCrimes_4
# Periods
# 2004JJ00            9.6                7.6                   4.4
# 2004JJ00            9.5                7.8                   4.4
# 2004JJ00           15.9               11.1                   8.0
# 2004JJ00           12.9               12.6                   5.5
# 2004JJ00           12.4               14.3                   5.0

# %%
plt.figure(figsize=(30, 6))
position = range(len(temp_table.index))
plt.subplot(1,3,1)
plt.title('Thefts')
plt.bar(temp_table['Title'], temp_table['TotalThefts_9'], color='gold')
plt.xticks(position, temp_table['Title'], rotation=80)
plt.subplot(1,3,2)
plt.title('Vandalism')
plt.bar(temp_table['Title'], temp_table['TotalVandalism_20'], color='g')
plt.xticks(position, temp_table['Title'], rotation=80)
plt.subplot(1,3,3)
plt.title('Violent Crimes')
plt.bar(temp_table['Title'], temp_table['TotalViolentCrimes_4'])
plt.xticks(position, temp_table['Title'], rotation=80)
# Out:
# ([<matplotlib.axis.XTick at 0x1272a7dd8>,
#   <matplotlib.axis.XTick at 0x1272a70f0>,
#   <matplotlib.axis.XTick at 0x1272c2748>,
#   <matplotlib.axis.XTick at 0x1272c9f98>,
#   <matplotlib.axis.XTick at 0x1272d0668>],
#  <a list of 5 Text xticklabel objects>)

# %% [markdown]
# - Another Characteristic Type

# %%
df_characteristics[df_characteristics['CategoryGroupID'] == 6]
# Out:
#                                        Title  CategoryGroupID  \
# 27       Age cat. 4 x gender: men, 12-17 yrs                6
# 28       Age cat. 4 x gender: men, 18-24 yrs                6
# 29       Age cat. 4 x gender: men, 25-34 yrs                6
# 30       Age cat. 4 x gender: men, 35-44 yrs                6
# 31       Age cat. 4 x gender: men, 45-54 yrs                6
# 32       Age cat. 4 x gender: men, 55-64 yrs                6
# 33       Age cat. 4 x gender: men, 65-74 yrs                6
# 34  Age cat. 4 x gender:men,75 yrs and older                6
# 35     Age cat. 4 x gender: women, 12-17 yrs                6
# 36     Age cat. 4 x gender: women, 18-24 yrs                6
# 37     Age cat. 4 x gender: women, 25-34 yrs                6
# 38     Age cat. 4 x gender: women, 35-44 yrs                6
# 39     Age cat. 4 x gender: women, 45-54 yrs                6
# 40     Age cat. 4 x gender: women, 55-64 yrs                6
# 41     Age cat. 4 x gender: women, 65-74 yrs                6
# 42  Age cat.4x gender,women,75 yrs and older                6
#
#     KeyCharacteristics
# 27                  90
# 28                  92
# 29                  94
# 30                  96
# 31                  98
# 32                 100
# 33                 102
# 34                 104
# 35                  91
# 36                  93
# 37                  95
# 38                  97
# 39                  99
# 40                 101
# 41                 103
# 42                 105

# %%
temp_table = df_victims_2004[df_victims_2004['CategoryGroupID'] == 6]

# %%
plt.figure(figsize=(30, 6))
position = range(len(temp_table.index))
plt.subplot(1,3,1)
plt.title('Thefts')
plt.bar(temp_table['Title'], temp_table['TotalThefts_9'], color='gold')
plt.xticks(position, temp_table['Title'], rotation=90)
plt.subplot(1,3,2)
plt.title('Vandalism')
plt.bar(temp_table['Title'], temp_table['TotalVandalism_20'], color='g')
plt.xticks(position, temp_table['Title'], rotation=90)
plt.subplot(1,3,3)
plt.title('Violent Crimes')
plt.bar(temp_table['Title'], temp_table['TotalViolentCrimes_4'])
plt.xticks(position, temp_table['Title'], rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x127c1c828>,
#   <matplotlib.axis.XTick at 0x127bcbd68>,
#   <matplotlib.axis.XTick at 0x127c34e10>,
#   <matplotlib.axis.XTick at 0x127c51da0>,
#   <matplotlib.axis.XTick at 0x127c57470>,
#   <matplotlib.axis.XTick at 0x127c57b00>,
#   <matplotlib.axis.XTick at 0x127c5a1d0>,
#   <matplotlib.axis.XTick at 0x127c5a860>,
#   <matplotlib.axis.XTick at 0x127c5aef0>,
#   <matplotlib.axis.XTick at 0x127c5e5c0>,
#   <matplotlib.axis.XTick at 0x127c5ec50>,
#   <matplotlib.axis.XTick at 0x127c61320>,
#   <matplotlib.axis.XTick at 0x127c619b0>,
#   <matplotlib.axis.XTick at 0x127c65080>,
#   <matplotlib.axis.XTick at 0x127c65710>,
#   <matplotlib.axis.XTick at 0x127c65da0>],
#  <a list of 16 Text xticklabel objects>)

# %% [markdown]
# ### Deaths; murder and manslaughter, crime scene in The Netherlands
# This table contains the number of persons died as a result of murder or manslaughter, where the crime scene is located in the Netherlands. The victims can be residents or non-residents. The data can be split by location of the crime, method, age and sex. The date of death is the criterion, the date of the act can be in the previous year. The ICD10 codes that belong to murder and manslaughter are X85-Y09.
# https://data.overheid.nl/data/dataset/deaths-murder-and-manslaughter-crime-scene-in-the-netherlands

# %%
r = requests.get("http://opendata.cbs.nl/ODataApi/OData/81453ENG")
service = json.loads(r.text)
for i in service['value']:
    print (i)
# Out:
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/81453ENG/TableInfos', 'name': 'TableInfos'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/81453ENG/UntypedDataSet', 'name': 'UntypedDataSet'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/81453ENG/TypedDataSet', 'name': 'TypedDataSet'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/81453ENG/DataProperties', 'name': 'DataProperties'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/81453ENG/CategoryGroups', 'name': 'CategoryGroups'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/81453ENG/Sex', 'name': 'Sex'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/81453ENG/Age', 'name': 'Age'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/81453ENG/Periods', 'name': 'Periods'}

# %%
request = requests.get("http://opendata.cbs.nl/ODataApi/OData/81453ENG")
tables = get_datasets(request)

# %%
for key in tables.keys():
    print(key)
# Out:
# DataProperties
# Periods
# TypedDataSet
# Age
# TableInfos
# UntypedDataSet
# Sex
# CategoryGroups

# %% [markdown]
# ---
# We can see the different tables

# %% [markdown]
# - Table infos

# %%
tables['TableInfos'].T
# Out:
#                                                                      0
# Catalog                                                            CBS
# DefaultPresentation       graphtype=Table&r=Age,Periods&k=Topics&t=Sex
# DefaultSelection     $filter=((Sex eq '1100')) and ((Age eq '10000'...
# Description          CONTENTS\r\n\r\n1. General information\r\n2. D...
# ExplanatoryText
# Frequency                                                       Yearly
# GraphTypes                                              Table,Bar,Line
# ID                                                                   0
# Identifier                                                    81453ENG
# Language                                                            en
# MetaDataModified                                   2017-12-28T02:00:00
# Modified                                           2017-12-28T02:00:00
# OutputStatus                                                   Regular
# Period                                                       1996-2016
# ReasonDelivery                                                  Change
# SearchPriority                                                       2
# ShortDescription     \nThis table contains the number of persons di...
# ShortTitle                             Deaths; murder and manslaughter
# Source                                                            CBS.
# Summary              Persons died as a result of murder or manslaug...
# Title                Deaths; murder and manslaughter, crime scene i...

# %% [markdown]
# - Periods

# %%
tables['Periods']
# Out:
#    Description       Key      Status Title
# 0         None  1996JJ00  Definitief  1996
# 1         None  1997JJ00  Definitief  1997
# 2         None  1998JJ00  Definitief  1998
# 3         None  1999JJ00  Definitief  1999
# 4         None  2000JJ00  Definitief  2000
# 5         None  2001JJ00  Definitief  2001
# 6         None  2002JJ00  Definitief  2002
# 7         None  2003JJ00  Definitief  2003
# 8         None  2004JJ00  Definitief  2004
# 9         None  2005JJ00  Definitief  2005
# 10        None  2006JJ00  Definitief  2006
# 11        None  2007JJ00  Definitief  2007
# 12        None  2008JJ00  Definitief  2008
# 13        None  2009JJ00  Definitief  2009
# 14        None  2010JJ00  Definitief  2010
# 15        None  2011JJ00  Definitief  2011
# 16        None  2012JJ00  Definitief  2012
# 17              2013JJ00  Definitief  2013
# 18              2014JJ00  Definitief  2014
# 19              2015JJ00  Definitief  2015
# 20              2016JJ00  Definitief  2016

# %% [markdown]
# - Data Properties

# %%
tables['DataProperties'].sort_values('Key')
# Out:
#    Datatype  Decimals Default  \
# 5       NaN       NaN     NaN
# 11      NaN       NaN     NaN
# 1       NaN       NaN     NaN
# 7   Integer       0.0    Zero
# 8   Integer       0.0    Zero
# 6   Integer       0.0    Zero
# 12  Integer       0.0    Zero
# 13  Integer       0.0    Zero
# 15  Integer       0.0    Zero
# 10  Integer       0.0    Zero
# 2       NaN       NaN     NaN
# 14  Integer       0.0    Zero
# 0       NaN       NaN     NaN
# 9      Long       0.0    Zero
# 3   Integer       0.0    Zero
# 4    Double       1.0    Zero
#
#                                           Description  ID  \
# 5   Since 2014, the breakdowns for both men and wo...   5
# 11  Since 2014, the breakdowns for both men and wo...  11
# 1                                                       1
# 7                                                       7
# 8                                                None   8
# 6                                                       6
# 12  House including garden, garage and shed of the...  12
# 13  Location for trade and services, like catering...  13
# 15                                                     15
# 10                                                     10
# 2                                                       2
# 14                                               None  14
# 0                                                       0
# 9                      Stabbing or battle weapon.\r\n   9
# 3   Murder: taking somebody's life, intentionally ...   3
# 4   Per 1 000 000 of the average population in the...   4
#
#                                       Key  ParentID  Position ReleasePolicy  \
# 5                                               NaN       NaN           NaN
# 11                                              NaN       NaN           NaN
# 1                                     Age       NaN       1.0           NaN
# 7                      BeatingOrKicking_4       5.0       6.0           NaN
# 8                               Firearm_5       5.0       7.0           NaN
# 6     HangingStrangulationOrSuffocation_3       5.0       5.0           NaN
# 12             HouseOfTheVictimOrOthers_8      11.0      10.0           NaN
# 13          LocationForTradeAndServices_9      11.0      11.0           NaN
# 15              OtherOrUnknownLocation_11      11.0      13.0           NaN
# 10                 OtherOrUnknownMethod_7       5.0       9.0           NaN
# 2                                 Periods       NaN       2.0          True
# 14                          PublicRoad_10      11.0      12.0           NaN
# 0                                     Sex       NaN       0.0           NaN
# 9                        StabbingWeapon_6       5.0       8.0           NaN
# 3   TotalVictimsOfMurderAndManslaughter_1       NaN       3.0           NaN
# 4     VictimsMurderManslaughterRelative_2       NaN       4.0           NaN
#
#                                        Title           Type  \
# 5         Method for murder and manslaughter     TopicGroup
# 11         Location murder and manslaughther     TopicGroup
# 1                                        Age      Dimension
# 7                         Beating or kicking          Topic
# 8                                    Firearm          Topic
# 6      Hanging, strangulation or suffocation          Topic
# 12             House of the victim or others          Topic
# 13           Location for trade and services          Topic
# 15                 Other or unknown location          Topic
# 10                   Other or unknown method          Topic
# 2                                    Periods  TimeDimension
# 14                               Public road          Topic
# 0                                        Sex      Dimension
# 9                            Stabbing weapon          Topic
# 3   Total victims of murder and manslaughter          Topic
# 4     Victims murder, manslaughter, relative          Topic
#
#                                  Unit               odata.type
# 5                                 NaN     Cbs.OData.TopicGroup
# 11                                NaN     Cbs.OData.TopicGroup
# 1                                 NaN      Cbs.OData.Dimension
# 7                              number          Cbs.OData.Topic
# 8                              number          Cbs.OData.Topic
# 6                              number          Cbs.OData.Topic
# 12                             number          Cbs.OData.Topic
# 13                             number          Cbs.OData.Topic
# 15                             number          Cbs.OData.Topic
# 10                             number          Cbs.OData.Topic
# 2                                 NaN  Cbs.OData.TimeDimension
# 14                             number          Cbs.OData.Topic
# 0                                 NaN      Cbs.OData.Dimension
# 9                              number          Cbs.OData.Topic
# 3                              number          Cbs.OData.Topic
# 4   Per mln of the average population          Cbs.OData.Topic

# %% [markdown]
# - Main Dataset

# %%
tables['TypedDataSet'].describe() #tables['UntypedDataSet'].describe() the untyped df it's plain text
# Out:
#        BeatingOrKicking_4   Firearm_5  HangingStrangulationOrSuffocation_3  \
# count          405.000000  405.000000                           405.000000
# mean             2.804938   12.446914                             3.488889
# std              3.843340   17.776814                             4.611436
# min              0.000000    0.000000                             0.000000
# 25%              0.000000    2.000000                             1.000000
# 50%              2.000000    5.000000                             2.000000
# 75%              3.000000   15.000000                             4.000000
# max             21.000000   91.000000                            33.000000
#
#        HouseOfTheVictimOrOthers_8         ID  LocationForTradeAndServices_9  \
# count                  405.000000  441.00000                     405.000000
# mean                    18.718519  220.00000                       2.614815
# std                     21.837831  127.44999                       3.884442
# min                      0.000000    0.00000                       0.000000
# 25%                      7.000000  110.00000                       0.000000
# 50%                     11.000000  220.00000                       1.000000
# 75%                     18.000000  330.00000                       3.000000
# max                    133.000000  440.00000                      21.000000
#
#        OtherOrUnknownLocation_11  OtherOrUnknownMethod_7  PublicRoad_10  \
# count                 405.000000              405.000000     405.000000
# mean                    7.906173                5.044444       9.012346
# std                    12.512413                6.911964      13.040962
# min                     0.000000                0.000000       0.000000
# 25%                     2.000000                1.000000       1.000000
# 50%                     4.000000                3.000000       4.000000
# 75%                     9.000000                6.000000      11.000000
# max                   101.000000               49.000000      70.000000
#
#        StabbingWeapon_6  TotalVictimsOfMurderAndManslaughter_1  \
# count        405.000000                             441.000000
# mean          14.466667                              35.972789
# std           17.610387                              45.513127
# min            0.000000                               0.000000
# 25%            5.000000                              12.000000
# 50%            9.000000                              21.000000
# 75%           15.000000                              36.000000
# max          103.000000                             264.000000
#
#        VictimsMurderManslaughterRelative_2
# count                           441.000000
# mean                             12.559637
# std                               8.088168
# min                               0.000000
# 25%                               6.400000
# 50%                              10.200000
# 75%                              17.100000
# max                              43.100000

# %%
df_deaths = tables['TypedDataSet']
df_deaths = df_deaths.loc[:, df_deaths.columns != 'ID']

# %%
df_deaths[['Sex','Age']].head()
# Out:
#     Sex    Age
# 0  1100  10000
# 1  1100  10000
# 2  1100  10000
# 3  1100  10000
# 4  1100  10000

# %% [markdown]
# Check how the dimension is codified

# %% [markdown]
# - Dimensions Sex and Age

# %%
tables['Sex']
# Out:
#   CategoryGroupID Description   Key                Title
# 0            None        None  1100  Total men and women
# 1            None        None  3000                  Men
# 2            None        None  4000                Women

# %%
tables['Age']
# Out:
#   CategoryGroupID Description    Key                  Title
# 0            None        None  10000         Total all ages
# 1            None        None  41410  Younger than 20 years
# 2            None        None  60300         20 to 30 years
# 3            None        None  60400         30 to 40 years
# 4            None        None  60500         40 to 50 years
# 5            None        None  60600         50 to 60 years
# 6            None        None  21400      60 years or older

# %% [markdown]
# ### Tables integration

# %%
df_deaths = pd.merge(df_deaths, tables['Sex'], left_on='Sex', right_on='Key', how='left')

# %%
df_deaths = pd.merge(df_deaths, tables['Age'], left_on='Age', right_on='Key', how='left')

# %%
df_deaths.index = df_deaths['Periods']

# %%
df_deaths.head()
# Out:
#             Age  BeatingOrKicking_4  Firearm_5  \
# Periods
# 1996JJ00  10000                13.0       86.0
# 1997JJ00  10000                 9.0       78.0
# 1998JJ00  10000                 9.0       74.0
# 1999JJ00  10000                21.0       89.0
# 2000JJ00  10000                 6.0       81.0
#
#           HangingStrangulationOrSuffocation_3  HouseOfTheVictimOrOthers_8  \
# Periods
# 1996JJ00                                 22.0                        97.0
# 1997JJ00                                 33.0                        70.0
# 1998JJ00                                 23.0                        66.0
# 1999JJ00                                 19.0                        95.0
# 2000JJ00                                 24.0                       101.0
#
#           LocationForTradeAndServices_9  OtherOrUnknownLocation_11  \
# Periods
# 1996JJ00                           15.0                       88.0
# 1997JJ00                           15.0                      101.0
# 1998JJ00                            9.0                       86.0
# 1999JJ00                           10.0                       67.0
# 2000JJ00                           21.0                       61.0
#
#           OtherOrUnknownMethod_7   Periods  PublicRoad_10       ...        \
# Periods                                                         ...
# 1996JJ00                    31.0  1996JJ00           40.0       ...
# 1997JJ00                    41.0  1997JJ00           51.0       ...
# 1998JJ00                    29.0  1998JJ00           47.0       ...
# 1999JJ00                    20.0  1999JJ00           58.0       ...
# 2000JJ00                    37.0  2000JJ00           40.0       ...
#
#          TotalVictimsOfMurderAndManslaughter_1  \
# Periods
# 1996JJ00                                   240
# 1997JJ00                                   237
# 1998JJ00                                   208
# 1999JJ00                                   230
# 2000JJ00                                   223
#
#           VictimsMurderManslaughterRelative_2  CategoryGroupID_x  \
# Periods
# 1996JJ00                                 15.5               None
# 1997JJ00                                 15.2               None
# 1998JJ00                                 13.2               None
# 1999JJ00                                 14.5               None
# 2000JJ00                                 14.0               None
#
#           Description_x Key_x              Title_x CategoryGroupID_y  \
# Periods
# 1996JJ00           None  1100  Total men and women              None
# 1997JJ00           None  1100  Total men and women              None
# 1998JJ00           None  1100  Total men and women              None
# 1999JJ00           None  1100  Total men and women              None
# 2000JJ00           None  1100  Total men and women              None
#
#          Description_y  Key_y         Title_y
# Periods
# 1996JJ00          None  10000  Total all ages
# 1997JJ00          None  10000  Total all ages
# 1998JJ00          None  10000  Total all ages
# 1999JJ00          None  10000  Total all ages
# 2000JJ00          None  10000  Total all ages
#
# [5 rows x 22 columns]

# %% [markdown]
# #### What to do?
# - Group the characteristics and see the time series per crime
# - Pick one year and see the characteristics
# - Group the year and see the characteristics
# - Group by crime type, group by general characteristics, choose last year

# %%
#Choose last period, and the total crimes 
df_deaths_2016 = df_deaths.loc['2016JJ00'][['Title_y','Title_x','BeatingOrKicking_4', 'Firearm_5', 'HangingStrangulationOrSuffocation_3', 'HouseOfTheVictimOrOthers_8', 'OtherOrUnknownMethod_7','StabbingWeapon_6']]

# %%
df_deaths_2016.head()
# Out:
#                         Title_y              Title_x  BeatingOrKicking_4  \
# Periods
# 2016JJ00         Total all ages  Total men and women                13.0
# 2016JJ00  Younger than 20 years  Total men and women                 3.0
# 2016JJ00         20 to 30 years  Total men and women                 2.0
# 2016JJ00         30 to 40 years  Total men and women                 3.0
# 2016JJ00         40 to 50 years  Total men and women                 2.0
#
#           Firearm_5  HangingStrangulationOrSuffocation_3  \
# Periods
# 2016JJ00       31.0                                  9.0
# 2016JJ00        1.0                                  0.0
# 2016JJ00        9.0                                  0.0
# 2016JJ00       13.0                                  3.0
# 2016JJ00        3.0                                  2.0
#
#           HouseOfTheVictimOrOthers_8  OtherOrUnknownMethod_7  StabbingWeapon_6
# Periods
# 2016JJ00                        58.0                     4.0              51.0
# 2016JJ00                         5.0                     2.0               2.0
# 2016JJ00                         8.0                     0.0              12.0
# 2016JJ00                        15.0                     1.0               8.0
# 2016JJ00                        10.0                     0.0              11.0

# %%
plt.figure(figsize=(30, 6))
position = range(len(df_deaths_2016.index))
plt.subplot(1,3,1)
plt.title('BeatingOrKicking')
plt.bar(df_deaths_2016['Title_y'], df_deaths_2016['BeatingOrKicking_4'], color='gold')
plt.xticks(position, df_deaths_2016['Title_y'], rotation=90)
plt.subplot(1,3,2)
plt.title('Firearm')
plt.bar(df_deaths_2016['Title_y'], df_deaths_2016['Firearm_5'], color='g')
plt.xticks(position, df_deaths_2016['Title_y'], rotation=90)
plt.subplot(1,3,3)
plt.title('HangingStrangulationOrSuffocation')
plt.bar(df_deaths_2016['Title_y'], df_deaths_2016['HangingStrangulationOrSuffocation_3'])
plt.xticks(position, df_deaths_2016['Title_y'], rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x1282fc940>,
#   <matplotlib.axis.XTick at 0x1282e7048>,
#   <matplotlib.axis.XTick at 0x128312390>,
#   <matplotlib.axis.XTick at 0x12832efd0>,
#   <matplotlib.axis.XTick at 0x128334668>,
#   <matplotlib.axis.XTick at 0x128334cc0>,
#   <matplotlib.axis.XTick at 0x128336358>,
#   <matplotlib.axis.XTick at 0x1283369b0>,
#   <matplotlib.axis.XTick at 0x12833b048>,
#   <matplotlib.axis.XTick at 0x12833b6a0>,
#   <matplotlib.axis.XTick at 0x12833bcf8>,
#   <matplotlib.axis.XTick at 0x12833e390>,
#   <matplotlib.axis.XTick at 0x12833e9e8>,
#   <matplotlib.axis.XTick at 0x128342080>,
#   <matplotlib.axis.XTick at 0x1283426d8>,
#   <matplotlib.axis.XTick at 0x128342d30>,
#   <matplotlib.axis.XTick at 0x1283453c8>,
#   <matplotlib.axis.XTick at 0x128345a20>,
#   <matplotlib.axis.XTick at 0x12834a0b8>,
#   <matplotlib.axis.XTick at 0x12834a710>,
#   <matplotlib.axis.XTick at 0x12834ad68>],
#  <a list of 21 Text xticklabel objects>)

# %% [markdown]
# ### Feelings of insecurity by background characteristics
# Feelings of insecurity due to crime Scared to be at home alone, or open the front door, scary places etc. 1997 - 2004 Changed on December 14 2005. Frequency: Discontinued.
# https://data.overheid.nl/data/dataset/feelings-of-insecurity-by-background-characteristics

# %%
r = requests.get("http://opendata.cbs.nl/ODataApi/OData/37775eng")
service = json.loads(r.text)
for i in service['value']:
    print (i)
# Out:
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37775eng/TableInfos', 'name': 'TableInfos'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37775eng/UntypedDataSet', 'name': 'UntypedDataSet'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37775eng/TypedDataSet', 'name': 'TypedDataSet'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37775eng/DataProperties', 'name': 'DataProperties'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37775eng/CategoryGroups', 'name': 'CategoryGroups'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37775eng/AllPersonalCharacteristics', 'name': 'AllPersonalCharacteristics'}
# {'url': 'http://opendata.cbs.nl/ODataApi/OData/37775eng/Periods', 'name': 'Periods'}

# %%
df_meta = json_normalize(service['value'])
df_meta.index = df_meta['name']
tableinfos = df_meta.loc['TableInfos']['url']
r_tableinfos = requests.get(tableinfos)
json_normalize(json.loads(r_tableinfos.text)['value']).T
# Out:
#                                                                      0
# Catalog                                                            CBS
# DefaultPresentation                                    graphType=table
# DefaultSelection
# Description          \r\nCONTENTS\r\n\r\n1. General information \r\...
# ExplanatoryText
# Frequency                                                 Discontinued
# GraphTypes                                              Table,Bar,Line
# ID                                                                   0
# Identifier                                                    37775eng
# Language                                                            en
# MetaDataModified                                   2005-12-14T02:00:00
# Modified                                           2005-12-14T02:00:00
# OutputStatus                                              Discontinued
# Period                                                     1997 - 2004
# ReasonDelivery                                               Undefined
# SearchPriority                                                       1
# ShortDescription     Feelings of insecurity due to crime\nScared to...
# ShortTitle                              Feelings of insecurity by type
# Source                                                            CBS.
# Summary              Feelings of insecurity due to crime\nScared to...
# Title                Feelings of insecurity by background character...

# %% [markdown]
# ### Crimes, type of crime
# This table contains figures on the number of registered crimes. These are broken down according to the type of crime, including figures on High Impact Crimes (theft / burglary, violent crimes, robberies, street robbery). The crime types shown are a selection of all crime types, and do not add up to the Total number of crimes.
# Data available from: 2014
# https://data.overheid.nl/data/dataset/misdrijven-soort-misdrijf

# %%
r = requests.get("https://dataderden.cbs.nl/ODataApi/OData/47005NED")
service = json.loads(r.text)
for i in service['value']:
    print (i)
# Out:
# {'url': 'https://dataderden.cbs.nl/ODataApi/OData/47005NED/TableInfos', 'name': 'TableInfos'}
# {'url': 'https://dataderden.cbs.nl/ODataApi/OData/47005NED/UntypedDataSet', 'name': 'UntypedDataSet'}
# {'url': 'https://dataderden.cbs.nl/ODataApi/OData/47005NED/TypedDataSet', 'name': 'TypedDataSet'}
# {'url': 'https://dataderden.cbs.nl/ODataApi/OData/47005NED/DataProperties', 'name': 'DataProperties'}
# {'url': 'https://dataderden.cbs.nl/ODataApi/OData/47005NED/CategoryGroups', 'name': 'CategoryGroups'}
# {'url': 'https://dataderden.cbs.nl/ODataApi/OData/47005NED/SoortMisdrijf', 'name': 'SoortMisdrijf'}
# {'url': 'https://dataderden.cbs.nl/ODataApi/OData/47005NED/Perioden', 'name': 'Perioden'}

# %%
df_meta = json_normalize(service['value'])
df_meta.index = df_meta['name']
tableinfos = df_meta.loc['TableInfos']['url']
r_tableinfos = requests.get(tableinfos)
json_normalize(json.loads(r_tableinfos.text)['value']).T
# Out:
#                                                                      0
# Catalog                                                        Politie
# DefaultPresentation  graphtype=Table&r=SoortMisdrijf&k=Perioden&t=T...
# DefaultSelection     $filter=((substringof('HJ',Perioden)))&$select...
# Description          INHOUDSOPGAVE\r\n\r\n1. Toelichting\r\n2. Defi...
# ExplanatoryText
# Frequency                                                 Onregelmatig
# GraphTypes                                                   Table,Bar
# ID                                                                   0
# Identifier                                                    47005NED
# Language                                                            nl
# MetaDataModified                                   2017-09-21T06:30:00
# Modified                                           2017-09-21T06:30:00
# OutputStatus                                                  Regulier
# Period                                                       2013-2017
# ReasonDelivery                                           Actualisering
# SearchPriority                                                       2
# ShortDescription     \nDeze tabel bevat cijfers over het aantal ger...
# ShortTitle                                  Misdrijven, soort misdrijf
# Source                                                 &copy; Politie,
# Summary                  Criminaliteit naar type delict\nType misdrijf
# Title                                       Misdrijven, soort misdrijf

# %% [markdown]
# ### Crime; type of crime, municipality
# This table contains figures on the number of registered crimes. These are broken down according to the type of crime, including figures on High Impact Crimes (theft / burglary, violent crimes, robberies, street robbery). The data is available per municipality. The crime types shown are a selection of all crime types, and do not add up to the Total number of crimes.
# Data available from: 2014.
# https://data.overheid.nl/data/dataset/misdrijven-soort-misdrijf-gemeente

# %%
r = requests.get("https://dataderden.cbs.nl/ODataApi/OData/47004NED")
service = json.loads(r.text)
for i in service['value']:
    print (i)
# Out:
# {'url': 'https://dataderden.cbs.nl/ODataApi/OData/47004NED/TableInfos', 'name': 'TableInfos'}
# {'url': 'https://dataderden.cbs.nl/ODataApi/OData/47004NED/UntypedDataSet', 'name': 'UntypedDataSet'}
# {'url': 'https://dataderden.cbs.nl/ODataApi/OData/47004NED/TypedDataSet', 'name': 'TypedDataSet'}
# {'url': 'https://dataderden.cbs.nl/ODataApi/OData/47004NED/DataProperties', 'name': 'DataProperties'}
# {'url': 'https://dataderden.cbs.nl/ODataApi/OData/47004NED/CategoryGroups', 'name': 'CategoryGroups'}
# {'url': 'https://dataderden.cbs.nl/ODataApi/OData/47004NED/SoortMisdrijf', 'name': 'SoortMisdrijf'}
# {'url': 'https://dataderden.cbs.nl/ODataApi/OData/47004NED/Gemeenten', 'name': 'Gemeenten'}
# {'url': 'https://dataderden.cbs.nl/ODataApi/OData/47004NED/Perioden', 'name': 'Perioden'}

# %%
df_meta = json_normalize(service['value'])
df_meta.index = df_meta['name']
tableinfos = df_meta.loc['TableInfos']['url']
r_tableinfos = requests.get(tableinfos)
json_normalize(json.loads(r_tableinfos.text)['value']).T
# Out:
#                                                                      0
# Catalog                                                        Politie
# DefaultPresentation  graphtype=Table&r=Gemeenten&k=SoortMisdrijf&t=...
# DefaultSelection     $filter=((SoortMisdrijf eq 'T001160') or (Soor...
# Description          INHOUDSOPGAVE\r\n\r\n1. Toelichting\r\n2. Defi...
# ExplanatoryText
# Frequency                                                 Onregelmatig
# GraphTypes                                               Table,Bar,Map
# ID                                                                   0
# Identifier                                                    47004NED
# Language                                                            nl
# MetaDataModified                                   2017-09-21T06:30:00
# Modified                                           2017-09-21T06:30:00
# OutputStatus                                                  Regulier
# Period                                                       2013-2017
# ReasonDelivery                                           Actualisering
# SearchPriority                                                       2
# ShortDescription     \nDeze tabel bevat cijfers over het aantal ger...
# ShortTitle                        Misdrijven; soort misdrijf, gemeente
# Source                                                 &copy; Politie,
# Summary                geregistreerde misdrijven\ntype misdrijf, regio
# Title                             Misdrijven; soort misdrijf, gemeente

# %%
from pandas.io.json import json_normalize

# %%
df_meta = json_normalize(service['value'])
df_meta
# Out:
#              name                                                url
# 0      TableInfos  https://dataderden.cbs.nl/ODataApi/OData/47004...
# 1  UntypedDataSet  https://dataderden.cbs.nl/ODataApi/OData/47004...
# 2    TypedDataSet  https://dataderden.cbs.nl/ODataApi/OData/47004...
# 3  DataProperties  https://dataderden.cbs.nl/ODataApi/OData/47004...
# 4  CategoryGroups  https://dataderden.cbs.nl/ODataApi/OData/47004...
# 5   SoortMisdrijf  https://dataderden.cbs.nl/ODataApi/OData/47004...
# 6       Gemeenten  https://dataderden.cbs.nl/ODataApi/OData/47004...
# 7        Perioden  https://dataderden.cbs.nl/ODataApi/OData/47004...

# %%
df_meta.index = df_meta['name']
#TableInfos
tableinfos = df_meta.loc['TableInfos']['url']

# %%
r_tableinfos = requests.get(tableinfos)
json_normalize(json.loads(r_tableinfos.text)['value']).T
# Out:
#                                                                      0
# Catalog                                                        Politie
# DefaultPresentation  graphtype=Table&r=Gemeenten&k=SoortMisdrijf&t=...
# DefaultSelection     $filter=((SoortMisdrijf eq 'T001160') or (Soor...
# Description          INHOUDSOPGAVE\r\n\r\n1. Toelichting\r\n2. Defi...
# ExplanatoryText
# Frequency                                                 Onregelmatig
# GraphTypes                                               Table,Bar,Map
# ID                                                                   0
# Identifier                                                    47004NED
# Language                                                            nl
# MetaDataModified                                   2017-09-21T06:30:00
# Modified                                           2017-09-21T06:30:00
# OutputStatus                                                  Regulier
# Period                                                       2013-2017
# ReasonDelivery                                           Actualisering
# SearchPriority                                                       2
# ShortDescription     \nDeze tabel bevat cijfers over het aantal ger...
# ShortTitle                        Misdrijven; soort misdrijf, gemeente
# Source                                                 &copy; Politie,
# Summary                geregistreerde misdrijven\ntype misdrijf, regio
# Title                             Misdrijven; soort misdrijf, gemeente
