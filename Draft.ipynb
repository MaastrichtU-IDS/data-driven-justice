# %%
# !python --version
# Out:
# Python 3.5.4 :: Anaconda, Inc.

# %%
import sys
print ("Python {}.{}.{}".format(sys.version_info[0],sys.version_info[1], sys.version_info[2]))
# Out:
# Python 3.5.4

# %% [markdown]
# ## Data Drive Justice
# ---

# %% [markdown]
# ### Guideline
# We are going to collect and analyze data about crimes that would help us to:
# - Reveal patterns relevant to criminal justice, When and where will the next crime take place in a specific region or community
# - Identify interesting uses of these data e.g. identify discriminatory practices or predict future crime events
# - Crime Classification: How does the socio-economic background of a person influence their probability of committing a crime? How does the socio-economic background of the criminal relate to the type of crime committed?
# - Perception of safety among citizens: What factors influence the perception of safety for European citizens?
# - Investigate the relationship between perception of crime and actual crime statistics within communities.
# - Can we explain regional differences, e.g. by looking at the demographics, prevalence of political affiliation or other interesting factors?

# %% [markdown]
# ### Data Science Pipeline
# ---

# %% [markdown]
# Exemplary Procedure Outline:
# Loop 1 (Data Exploration)
# Specify a set of research questions
# Create a data pipeline strategy
# Find and collect datasets
# Have a look at descriptive statistics
# Create new features as needed
# With the data on hand, continue to ask questions:
# Do we still have the same research questions?
# De we still have the same strategy?
# Shall we find other sources?
# ​
# Loop 2 (Data Integration)
# Integrate raw data
# Write scripts for cleaning and aggregation
# Feature selection
# Variable interpretation
# Find correlation between variables
# With the summary on hand, continue to ask question:
# Do we need different variables?
# Do we need to normalize our features?
# Are we still confident we can answer the research question?
# ​
# Loop 3 (Data Analysis)
# Identify the method to respond the target variables
# If is a crime pattern then: Anomaly Detection
# If is a crime circle then: Time Series
# If is a crime category then: Classification
# If is the quantity of crimes then: Regression
# If is a concept and not a target variable then: Density unsupervised
# Etc. (All options enunciative but not limitative)
# Design a concept to visualize the outcome
# Choose and develop the algorithm (e.g. if Classification, SVM or Bayes?)
# Plot the outcomes
# With the summary on hand, ask…
# Does the outcome makes sense?
# What does the important variables mean? (on “human” language)
# How improve the outcome? (add more target variables? Change it? Change the parameters? Change the method?)
# ​
# Loop 4 (Data Communication)
# Document the procedures
# Versioning control of script for replicable science
# Develop a Data Storytelling
# With the Data-story (Notebook, Tableau story, R-Markdown, Slides, etc) on hand, ask… What’s next?
# Improve the model?
# Improve the data?
# Join more researchers to the problem?

# %%
import pandas as pd
import requests
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### European Summary

# %%
data = pd.read_csv('data/crim_hist.tsv', sep='\t', encoding="utf-8")
#data

# %%
data.columns
# Out:
# Index(['unit,geo\time', '2000 ', '1999 ', '1998 ', '1997 ', '1996 ', '1995 ',
#        '1994 ', '1993 ', '1992 ', '1991 ', '1990 ', '1989 ', '1988 ', '1987 ',
#        '1986 ', '1985 ', '1984 ', '1983 ', '1982 ', '1981 ', '1980 ', '1979 ',
#        '1978 ', '1977 ', '1976 ', '1975 ', '1974 ', '1973 ', '1972 ', '1971 ',
#        '1970 ', '1969 ', '1968 ', '1967 ', '1966 ', '1965 ', '1964 ', '1963 ',
#        '1962 ', '1961 ', '1960 ', '1959 ', '1958 ', '1957 ', '1956 ', '1955 ',
#        '1954 ', '1953 ', '1952 ', '1951 ', '1950 '],
#       dtype='object')

# %% [markdown]
# ### Victimhood; offenses and offense groups, 1992-2004
# http://opendata.cbs.nl/ODataApi/OData/37685

# %%
pd.read_csv('data/37685ENG_UntypedDataSet_23112017_155707.csv', sep=';', encoding="utf-8")
# Out:
#     ID   Periods  TotalVictimsOfCrimes_1  SingleVictims_2  MultipleVictims_3  \
# 0    0  1992JJ00                    24.3             18.5                5.9
# 1    1  1993JJ00                    25.0             19.1                6.0
# 2    2  1994JJ00                    26.0             20.8                5.2
# 3    3  1995JJ00                    25.9             20.2                5.7
# 4    4  1996JJ00                    23.1             18.6                4.6
# 5    5  1997JJ00                    25.5             20.4                5.2
# 6    6  1998JJ00                    26.2             20.7                5.4
# 7    7  1999JJ00                    26.2             20.6                5.5
# 8    8  2000JJ00                    25.7             20.7                5.0
# 9    9  2001JJ00                    24.9             19.6                5.4
# 10  10  2002JJ00                    27.2             21.4                5.8
# 11  11  2003JJ00                    25.6             20.5                5.1
# 12  12  2004JJ00                    25.4             20.0                5.3
#
#     TotalViolentCrime_4  SexualCrimes_5  SexualCrimesOnlyWomen_6  Assault_7  \
# 0                   5.4             1.1                      2.1        2.0
# 1                   5.1             1.1                      2.2        1.6
# 2                   5.2             1.3                      2.5        1.3
# 3                   5.4             1.1                      2.2        1.8
# 4                   4.2             0.7                      1.5        1.2
# 5                   5.0             1.2                      2.1        1.4
# 6                   5.6             1.1                      2.0        1.8
# 7                   5.5             1.1                      1.9        1.6
# 8                   5.0             1.0                      1.8        1.3
# 9                   5.8             1.1                      1.8        1.8
# 10                  6.0             1.2                      2.2        1.7
# 11                  5.7             0.9                      1.5        1.9
# 12                  5.2             0.8                      1.5        1.6
#
#     Threats_8       ...        TheftFromCarsIntCarOwnersOnly_17  \
# 0         2.9       ...                                     4.4
# 1         2.8       ...                                     5.0
# 2         3.1       ...                                     3.9
# 3         2.8       ...                                     4.0
# 4         2.5       ...                                     3.6
# 5         2.7       ...                                     3.5
# 6         3.1       ...                                     2.9
# 7         3.3       ...                                     3.3
# 8         3.0       ...                                     3.1
# 9         3.4       ...                                     3.6
# 10        3.7       ...                                     4.3
# 11        3.5       ...                                     4.0
# 12        3.2       ...                                     3.5
#
#     Pickpocketing_18  OtherTheft_19  TotalCasesOfVandalism_20  \
# 0                2.1            4.0                       8.7
# 1                2.2            3.4                      10.3
# 2                2.4            3.3                       9.9
# 3                2.6            3.7                       9.7
# 4                1.8            3.4                       8.8
# 5                2.0            3.3                      10.4
# 6                2.2            3.7                      11.1
# 7                2.0            3.0                      11.6
# 8                2.0            3.1                      11.0
# 9                1.9            2.8                      10.5
# 10               2.0            3.1                      12.1
# 11               1.9            2.7                      11.1
# 12               1.6            3.0                      11.4
#
#     CarVandalismTheftFromCarsExterior_21  CarTheftsExtVandalismCarOwners_22  \
# 0                                    5.4                               12.0
# 1                                    6.4                               14.3
# 2                                    5.9                               13.1
# 3                                    6.0                               12.9
# 4                                    5.8                               12.5
# 5                                    6.2                               11.2
# 6                                    6.6                               12.0
# 7                                    7.1                               12.5
# 8                                    7.0                               12.1
# 9                                    6.6                               11.2
# 10                                   7.8                               13.0
# 11                                   7.6                               12.6
# 12                                   7.5                               12.3
#
#     OtherFormsOfVandalism_23  HitAndRunAccidents_24  HarassmentByPhone_25  \
# 0                        3.5                    1.5                   8.3
# 1                        4.3                    1.2                   7.6
# 2                        4.3                    1.6                   6.6
# 3                        3.9                    1.4                   7.1
# 4                        3.4                    1.3                   6.2
# 5                        4.8                    1.3                   7.2
# 6                        5.1                    1.2                   6.9
# 7                        5.1                    1.5                   6.9
# 8                        4.8                    1.5                   5.7
# 9                        4.4                    1.3                   5.2
# 10                       5.0                    1.5                   4.6
# 11                       4.2                    1.4                   4.8
# 12                       4.7                    1.3                   4.7
#
#     OtherCrimes_26
# 0              0.5
# 1              0.8
# 2              0.6
# 3              0.7
# 4              0.6
# 5              0.5
# 6              0.7
# 7              0.6
# 8              0.6
# 9              0.7
# 10             0.7
# 11             0.8
# 12             0.8
#
# [13 rows x 28 columns]

# %% [markdown]
# ### European Social Survey
# http://www.europeansocialsurvey.org/data/round-index.html

# %%
data = pd.read_stata('data/ESS8e01.stata/ESS8e01.dta', convert_categoricals=False)
#sr = pd.io.stata.StataReader('../Downloads/ESS8e01.stata/ESS8e01.dta')
#vl = sr.value_labels()
#sr.close()

# %%
data.head()
# Out:
#       name  essround edition    proddate  idno cntry  nwspol  netusoft  \
# 0  ESS8e01       8.0     1.0  31.10.2017   1.0    AT   120.0       4.0
# 1  ESS8e01       8.0     1.0  31.10.2017   2.0    AT   120.0       5.0
# 2  ESS8e01       8.0     1.0  31.10.2017   4.0    AT    30.0       2.0
# 3  ESS8e01       8.0     1.0  31.10.2017   6.0    AT    30.0       5.0
# 4  ESS8e01       8.0     1.0  31.10.2017  10.0    AT    30.0       5.0
#
#    netustm  ppltrst    ...     inwshh  inwsmm  inwdde  inwmme  inwyye  inwehh  \
# 0    180.0      8.0    ...        7.0    37.0     5.0    12.0  2016.0     8.0
# 1    120.0      6.0    ...        9.0    39.0    25.0    11.0  2016.0    11.0
# 2   6666.0      5.0    ...       17.0    17.0    22.0    11.0  2016.0    18.0
# 3    120.0      6.0    ...       19.0     9.0    11.0    10.0  2016.0    19.0
# 4    180.0      5.0    ...       10.0    31.0     1.0    12.0  2016.0    11.0
#
#    inwemm  inwtm   dweight   pweight
# 0    33.0   50.0  0.611677  0.370393
# 1    10.0   86.0  1.223354  0.370393
# 2     0.0   38.0  0.389058  0.370393
# 3    59.0   46.0  0.642594  0.370393
# 4    49.0   70.0  3.432402  0.370393
#
# [5 rows x 499 columns]

# %% [markdown]
# ### JSON Editor
# http://jsoneditoronline.org/
#
# ### Data Portal
# https://data.overheid.nl/data/dataset?q=crime&sort=score+desc%2C+modified+desc%2C+metadata_modified+desc

# %% [markdown]
# ### Victims of frequently occurring crime
# https://data.overheid.nl/data/dataset/victims-of-frequently-occurring-crime
# https://opendata.cbs.nl/dataportaal/portal.html?/CBS/nl/dataset/table?graphtype=Table&tableId=37685ENG&_catalog=CBS&_la=nl&_theme=1057

# %%
r = requests.get("http://opendata.cbs.nl/ODataApi/OData/37685ENG")

# %%
service = json.loads(r.text)

# %%
for i in service['value']:
    print (i)
# Out:
# {'name': 'TableInfos', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37685ENG/TableInfos'}
# {'name': 'UntypedDataSet', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37685ENG/UntypedDataSet'}
# {'name': 'TypedDataSet', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37685ENG/TypedDataSet'}
# {'name': 'DataProperties', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37685ENG/DataProperties'}
# {'name': 'CategoryGroups', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37685ENG/CategoryGroups'}
# {'name': 'Periods', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37685ENG/Periods'}

# %%
data = requests.get("http://opendata.cbs.nl/ODataApi/OData/37685ENG/TypedDataSet")

# %%
#json.loads(data.text)

# %% [markdown]
# ### Crime victims by personal characteristics
# Crime victims by background characteristics: sex, age, highest level of education, number of addresses per km2 of the place of residence 1997 - 2004 Changed on November 07 2005. Frequency: Discontinued.
# https://data.overheid.nl/data/dataset/crime-victims-by-personal-characteristics

# %%
r = requests.get("http://opendata.cbs.nl/ODataApi/OData/37957ENG")
service = json.loads(r.text)
for i in service['value']:
    print (i)
# Out:
# {'name': 'TableInfos', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37957ENG/TableInfos'}
# {'name': 'UntypedDataSet', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37957ENG/UntypedDataSet'}
# {'name': 'TypedDataSet', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37957ENG/TypedDataSet'}
# {'name': 'DataProperties', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37957ENG/DataProperties'}
# {'name': 'CategoryGroups', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37957ENG/CategoryGroups'}
# {'name': 'PersonalCharacteristics', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37957ENG/PersonalCharacteristics'}
# {'name': 'Periods', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37957ENG/Periods'}

# %% [markdown]
# ### Deaths; murder and manslaughter, crime scene in The Netherlands
# This table contains the number of persons died as a result of murder or manslaughter, where the crime scene is located in the Netherlands. The victims can be residents or non-residents. The data can be split by location of the crime, method, age and sex. The date of death is the criterion, the date of the act can be in the previous year. The ICD10 codes that belong to murder and manslaughter are X85-Y09.
# https://data.overheid.nl/data/dataset/deaths-murder-and-manslaughter-crime-scene-in-the-netherlands

# %%
r = requests.get("http://opendata.cbs.nl/ODataApi/OData/81453ENG")
service = json.loads(r.text)
for i in service['value']:
    print (i)
# Out:
# {'name': 'TableInfos', 'url': 'http://opendata.cbs.nl/ODataApi/OData/81453ENG/TableInfos'}
# {'name': 'UntypedDataSet', 'url': 'http://opendata.cbs.nl/ODataApi/OData/81453ENG/UntypedDataSet'}
# {'name': 'TypedDataSet', 'url': 'http://opendata.cbs.nl/ODataApi/OData/81453ENG/TypedDataSet'}
# {'name': 'DataProperties', 'url': 'http://opendata.cbs.nl/ODataApi/OData/81453ENG/DataProperties'}
# {'name': 'CategoryGroups', 'url': 'http://opendata.cbs.nl/ODataApi/OData/81453ENG/CategoryGroups'}
# {'name': 'Sex', 'url': 'http://opendata.cbs.nl/ODataApi/OData/81453ENG/Sex'}
# {'name': 'Age', 'url': 'http://opendata.cbs.nl/ODataApi/OData/81453ENG/Age'}
# {'name': 'Periods', 'url': 'http://opendata.cbs.nl/ODataApi/OData/81453ENG/Periods'}

# %% [markdown]
# ### Feelings of insecurity by background characteristics
# Feelings of insecurity due to crime Scared to be at home alone, or open the front door, scary places etc. 1997 - 2004 Changed on December 14 2005. Frequency: Discontinued.
# https://data.overheid.nl/data/dataset/feelings-of-insecurity-by-background-characteristics

# %%
r = requests.get("http://opendata.cbs.nl/ODataApi/OData/37775eng")
service = json.loads(r.text)
for i in service['value']:
    print (i)
# Out:
# {'name': 'TableInfos', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37775eng/TableInfos'}
# {'name': 'UntypedDataSet', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37775eng/UntypedDataSet'}
# {'name': 'TypedDataSet', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37775eng/TypedDataSet'}
# {'name': 'DataProperties', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37775eng/DataProperties'}
# {'name': 'CategoryGroups', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37775eng/CategoryGroups'}
# {'name': 'AllPersonalCharacteristics', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37775eng/AllPersonalCharacteristics'}
# {'name': 'Periods', 'url': 'http://opendata.cbs.nl/ODataApi/OData/37775eng/Periods'}

# %% [markdown]
# ### Crimes, type of crime
# This table contains figures on the number of registered crimes. These are broken down according to the type of crime, including figures on High Impact Crimes (theft / burglary, violent crimes, robberies, street robbery). The crime types shown are a selection of all crime types, and do not add up to the Total number of crimes.
# Data available from: 2014
# https://data.overheid.nl/data/dataset/misdrijven-soort-misdrijf

# %%
r = requests.get("https://dataderden.cbs.nl/ODataApi/OData/47005NED")
service = json.loads(r.text)
for i in service['value']:
    print (i)
# Out:
# {'name': 'TableInfos', 'url': 'https://dataderden.cbs.nl/ODataApi/OData/47005NED/TableInfos'}
# {'name': 'UntypedDataSet', 'url': 'https://dataderden.cbs.nl/ODataApi/OData/47005NED/UntypedDataSet'}
# {'name': 'TypedDataSet', 'url': 'https://dataderden.cbs.nl/ODataApi/OData/47005NED/TypedDataSet'}
# {'name': 'DataProperties', 'url': 'https://dataderden.cbs.nl/ODataApi/OData/47005NED/DataProperties'}
# {'name': 'CategoryGroups', 'url': 'https://dataderden.cbs.nl/ODataApi/OData/47005NED/CategoryGroups'}
# {'name': 'SoortMisdrijf', 'url': 'https://dataderden.cbs.nl/ODataApi/OData/47005NED/SoortMisdrijf'}
# {'name': 'Perioden', 'url': 'https://dataderden.cbs.nl/ODataApi/OData/47005NED/Perioden'}

# %% [markdown]
# ### Crime; type of crime, municipality
# This table contains figures on the number of registered crimes. These are broken down according to the type of crime, including figures on High Impact Crimes (theft / burglary, violent crimes, robberies, street robbery). The data is available per municipality. The crime types shown are a selection of all crime types, and do not add up to the Total number of crimes.
# Data available from: 2014.
# https://data.overheid.nl/data/dataset/misdrijven-soort-misdrijf-gemeente

# %%
r = requests.get("https://dataderden.cbs.nl/ODataApi/OData/47004NED")
service = json.loads(r.text)
for i in service['value']:
    print (i)
# Out:
# {'name': 'TableInfos', 'url': 'https://dataderden.cbs.nl/ODataApi/OData/47004NED/TableInfos'}
# {'name': 'UntypedDataSet', 'url': 'https://dataderden.cbs.nl/ODataApi/OData/47004NED/UntypedDataSet'}
# {'name': 'TypedDataSet', 'url': 'https://dataderden.cbs.nl/ODataApi/OData/47004NED/TypedDataSet'}
# {'name': 'DataProperties', 'url': 'https://dataderden.cbs.nl/ODataApi/OData/47004NED/DataProperties'}
# {'name': 'CategoryGroups', 'url': 'https://dataderden.cbs.nl/ODataApi/OData/47004NED/CategoryGroups'}
# {'name': 'SoortMisdrijf', 'url': 'https://dataderden.cbs.nl/ODataApi/OData/47004NED/SoortMisdrijf'}
# {'name': 'Gemeenten', 'url': 'https://dataderden.cbs.nl/ODataApi/OData/47004NED/Gemeenten'}
# {'name': 'Perioden', 'url': 'https://dataderden.cbs.nl/ODataApi/OData/47004NED/Perioden'}
